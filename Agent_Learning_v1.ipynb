# %%
import pygame
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import math
import random
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class IntelliGoal(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(s):
        super(IntelliGoal, s).__init__()
        
        s.screen_width = 1240
        s.screen_height = 800
        s.border_width = 10
        s.screen = None
        
        s.goal_radius = 20
        s.player_radius = 10
        
        s.player_speed = 1
        
        
        # State information
        s.player_x = 0
        s.player_y = 0
        s.goal_x = 0
        s.goal_y = 0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        s.done = False
        s.reward = 0
        
        
        # State and Action spaces
        s.action_space = spaces.Discrete(5) # 0: No movement, 1: Up, 2: Down, 3: Left, 4: Right
        # observation space = [player_x, player_y, goal_x, goal_y]
        s.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 0]), 
            high=np.array([s.screen_width, s.screen_height, s.screen_width, s.screen_height]), 
            dtype=np.int32
        )
    
    def seed(s, seed=None):
        if seed is not None and (seed < 0 or seed >= 2**32):
            raise ValueError("Seed must be between 0 and 2**32 - 1")
        s.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]
        
    def reset(s, seed=0):
        s.seed(seed)
        
        s.player_x = s.screen_width // 2
        s.player_y = s.screen_height // 2
        
        s.goal_x, s.goal_y = s.respawn_goal()
        
        s.reward = 0
        s.done = False
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        return s.state, {}
    
    def respawn_goal(s):
        s.goal_x = s.player_x + random.randint(-50, 50)
        s.goal_y = s.player_y + random.randint(-50, 50)
        
        # clip the goal to the screen
        offset = s.border_width + s.goal_radius
        s.goal_x = min( max(s.goal_x, offset), s.screen_width - offset)
        s.goal_y = min( max(s.goal_y, offset), s.screen_height - offset)
        
        pygame.time.wait(300)
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        return s.goal_x, s.goal_y
        
    def step(s, action):
        #################
        #do more here
        #################
        
        s.do_action(action)
        s.reward -= 0.0001
    
        return s.state, s.reward, s.done, False, {}
        
   
    def do_action(s, action):
        if not s.action_space.contains(action):
            print("Invalid Action")
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        s.player_x += (action == 4)*s.player_speed - (action == 3)*s.player_speed 
        s.player_y += (action == 2)*s.player_speed - (action == 1)*s.player_speed
        
        # Distance between player and goal
        distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)

        # Check if the red dot touches the border
        if s.player_x not in range(s.border_width, s.screen_width - s.border_width) or s.player_y not in range(s.border_width, s.screen_height - s.border_width):
            s.player_x, s.player_y = s.screen_width // 2, s.screen_height // 2

        # Check if the goal is reached within a certain range
        if distance < s.goal_radius + s.player_radius:
            s.goal_x, s.goal_y = s.respawn_goal()
            s.reward += 0.5
            s.done = True
            
    
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        if s.prev_distance > distance:
            s.reward += 0.010
        if s.prev_distance < distance:
            s.reward -= 0.015
     
    
    def keyboard_input(s):
        keys = pygame.key.get_pressed()
        # 1: Up, 2: Down, 3: Left, 4: Right
        if keys[pygame.K_UP]:
            return 1
        if keys[pygame.K_DOWN]:
            return 2
        if keys[pygame.K_LEFT]:
            return 3
        if keys[pygame.K_RIGHT]:
            return 4
        return 0
        
    
    def render(s, mode = 'human'):
        if s.screen == None:
            pygame.init()
            s.screen = pygame.display.set_mode((s.screen_width, s.screen_height))
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
        s.player_x, s.player_y, s.goal_x, s.goal_y = s.state
        
        s.screen.fill((0, 0, 0))
        RED = (255, 0, 0)
        BLUE = (0, 0, 255)
        BORDER_COLOR = (255, 255, 0)
        
        # Draw the border
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.border_width, s.screen_height))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, s.screen_height - s.border_width, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (s.screen_width - s.border_width, 0, s.border_width, s.screen_height))

        # Draw the red dot
        pygame.draw.circle(s.screen, RED, (s.player_x, s.player_y), 10)

        # Draw the blue dot
        pygame.draw.circle(s.screen, BLUE, (s.goal_x, s.goal_y), s.goal_radius)
        
        #Display Reward on pygame screen
        font = pygame.font.Font(None, 36)
        text = font.render("Reward: " + str(round(s.reward, 5)), True, (255, 255, 255))
        s.screen.blit(text, (10, 10))
        
        pygame.display.update()
    
    def close(s):
        pygame.quit()

# %%
# Test Env with keyboard input actions
# test_env = IntelliGoal()
# test_env.reset(0)
# done = False
# i = 1

# while True:
#     try:
#         test_env.render()
#         action = test_env.keyboard_input()
#         state, reward, done, _, _i = test_env.step(action)
#         if done:
#             print("Reward at step - ", i, " : ", round(reward, 5))
#             i += 1
#             test_env.reset(0)
#     except:
#         print("Environment Closed")
#         break
# Out:
# Environment Closed

# %% [markdown]
# # PPO Learning Algorithm

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
import torch
device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
    print("Using GPU")

# %%
env = IntelliGoal()
check_env(env)

# %%
def make_env():
    env = IntelliGoal()
    return env

env = DummyVecEnv([make_env for _ in range(1)])

model = PPO("MlpPolicy", env, verbose=1, device=device)
# Out:
# Using cpu device

# %%
# Start training
save_path = "./models/intelli_goal_a2"
# set teh goal to spawn close - +_ 50 pixels initially

# if os.path.exists(save_path):
#     os.remove(save_path)
# try:
#     model.learn(total_timesteps=9999999999)
#     model.save(save_path)
# except KeyboardInterrupt:
#     print("Training Interrupted")
#     model.save(save_path)

# %%
# Load and resume training
try:
    model.load(save_path)
    model.learn(total_timesteps=9999999999999)
    model.save(save_path)
except KeyboardInterrupt:
    print("Training Interrupted")
    print("Saving Model")
    model.save(save_path)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1973 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1258        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015099455 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.49e+05    |
# |    n_updates            | 9074        |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 6.91e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1115        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012664999 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.7e+05     |
# |    n_updates            | 9084        |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 3.52e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1064         |
# |    iterations           | 4            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0083787665 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.47e+04     |
# |    n_updates            | 9094         |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 1.09e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1052         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0073461705 |
# |    clip_fraction        | 0.0645       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | -8.34e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87e+03     |
# |    n_updates            | 9104         |
# |    policy_gradient_loss | -0.000717    |
# |    value_loss           | 7.06e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 6           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010049609 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 5.81e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.88e+03    |
# |    n_updates            | 9114        |
# |    policy_gradient_loss | -0.00353    |
# |    value_loss           | 1.75e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1032         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0026373516 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.44e+04     |
# |    n_updates            | 9124         |
# |    policy_gradient_loss | -0.000738    |
# |    value_loss           | 1.69e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1031         |
# |    iterations           | 8            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0014004812 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 2.04e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.87e+05     |
# |    n_updates            | 9134         |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 3.9e+05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1029         |
# |    iterations           | 9            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0035636472 |
# |    clip_fraction        | 0.000928     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | -0.00093     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.56e+05     |
# |    n_updates            | 9144         |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 6.92e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1027         |
# |    iterations           | 10           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0030731324 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.36e+05     |
# |    n_updates            | 9154         |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 1.07e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1009         |
# |    iterations           | 11           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0022693295 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.21e+05     |
# |    n_updates            | 9164         |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 1.46e+06     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1003       |
# |    iterations           | 12         |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00533526 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.54      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.7e+05    |
# |    n_updates            | 9174       |
# |    policy_gradient_loss | -0.00387   |
# |    value_loss           | 1.97e+06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 990         |
# |    iterations           | 13          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.001356106 |
# |    clip_fraction        | 0.000244    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26e+06    |
# |    n_updates            | 9184        |
# |    policy_gradient_loss | -0.00072    |
# |    value_loss           | 2.56e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 986          |
# |    iterations           | 14           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0015308218 |
# |    clip_fraction        | 0.000391     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.66e+06     |
# |    n_updates            | 9194         |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 3.32e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 970          |
# |    iterations           | 15           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0010743951 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.14e+06     |
# |    n_updates            | 9204         |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 4.22e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 949           |
# |    iterations           | 16            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 32768         |
# | train/                  |               |
# |    approx_kl            | 0.00076149544 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.53         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.55e+06      |
# |    n_updates            | 9214          |
# |    policy_gradient_loss | -0.000584     |
# |    value_loss           | 5.2e+06       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 17           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0007674056 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.15e+06     |
# |    n_updates            | 9224         |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 6.24e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 18           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0029263073 |
# |    clip_fraction        | 0.0042       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.68e+06     |
# |    n_updates            | 9234         |
# |    policy_gradient_loss | -0.00301     |
# |    value_loss           | 7.38e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 892           |
# |    iterations           | 19            |
# |    time_elapsed         | 43            |
# |    total_timesteps      | 38912         |
# | train/                  |               |
# |    approx_kl            | 0.00045150163 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.3e+06       |
# |    n_updates            | 9244          |
# |    policy_gradient_loss | -0.000389     |
# |    value_loss           | 8.57e+06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 20           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0020797588 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 6.56e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.93e+06     |
# |    n_updates            | 9254         |
# |    policy_gradient_loss | -0.000944    |
# |    value_loss           | 9.81e+06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 850           |
# |    iterations           | 21            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 43008         |
# | train/                  |               |
# |    approx_kl            | 0.00041352992 |
# |    clip_fraction        | 0.00127       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.55e+06      |
# |    n_updates            | 9264          |
# |    policy_gradient_loss | -0.00054      |
# |    value_loss           | 1.11e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 22           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0010712245 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.33e+06     |
# |    n_updates            | 9274         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 1.26e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 856           |
# |    iterations           | 23            |
# |    time_elapsed         | 54            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00035846612 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.17e+06      |
# |    n_updates            | 9284          |
# |    policy_gradient_loss | -0.000663     |
# |    value_loss           | 1.42e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 24           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0014582479 |
# |    clip_fraction        | 0.00107      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 1.19e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.04e+06     |
# |    n_updates            | 9294         |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 1.59e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 868           |
# |    iterations           | 25            |
# |    time_elapsed         | 58            |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00036147193 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.69e+06      |
# |    n_updates            | 9304          |
# |    policy_gradient_loss | -0.000703     |
# |    value_loss           | 1.76e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 26           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0005563356 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.65e+06     |
# |    n_updates            | 9314         |
# |    policy_gradient_loss | -0.000733    |
# |    value_loss           | 1.96e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 868          |
# |    iterations           | 27           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0014553149 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+07     |
# |    n_updates            | 9324         |
# |    policy_gradient_loss | -0.00179     |
# |    value_loss           | 2.17e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 871           |
# |    iterations           | 28            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00030573294 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.2e+07       |
# |    n_updates            | 9334          |
# |    policy_gradient_loss | -3.75e-05     |
# |    value_loss           | 2.39e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 874          |
# |    iterations           | 29           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0006020636 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+07     |
# |    n_updates            | 9344         |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 2.6e+07      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 877           |
# |    iterations           | 30            |
# |    time_elapsed         | 70            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00042219326 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.39e+07      |
# |    n_updates            | 9354          |
# |    policy_gradient_loss | -0.000597     |
# |    value_loss           | 2.83e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 872           |
# |    iterations           | 31            |
# |    time_elapsed         | 72            |
# |    total_timesteps      | 63488         |
# | train/                  |               |
# |    approx_kl            | 0.00012676662 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.52e+07      |
# |    n_updates            | 9364          |
# |    policy_gradient_loss | -6.09e-05     |
# |    value_loss           | 3.06e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 869           |
# |    iterations           | 32            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 0.00020223612 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.64e+07      |
# |    n_updates            | 9374          |
# |    policy_gradient_loss | -0.000353     |
# |    value_loss           | 3.3e+07       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 33           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0010654663 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.78e+07     |
# |    n_updates            | 9384         |
# |    policy_gradient_loss | -0.000611    |
# |    value_loss           | 3.55e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 869          |
# |    iterations           | 34           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0007264345 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.86e+07     |
# |    n_updates            | 9394         |
# |    policy_gradient_loss | -0.000813    |
# |    value_loss           | 3.8e+07      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 870           |
# |    iterations           | 35            |
# |    time_elapsed         | 82            |
# |    total_timesteps      | 71680         |
# | train/                  |               |
# |    approx_kl            | 0.00037459476 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.03e+07      |
# |    n_updates            | 9404          |
# |    policy_gradient_loss | -0.00114      |
# |    value_loss           | 4.05e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 36           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0001803934 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.18e+07     |
# |    n_updates            | 9414         |
# |    policy_gradient_loss | -0.000553    |
# |    value_loss           | 4.33e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 860          |
# |    iterations           | 37           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0001614828 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.3e+07      |
# |    n_updates            | 9424         |
# |    policy_gradient_loss | -0.00033     |
# |    value_loss           | 4.63e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 851           |
# |    iterations           | 38            |
# |    time_elapsed         | 91            |
# |    total_timesteps      | 77824         |
# | train/                  |               |
# |    approx_kl            | 0.00030362862 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.48e+07      |
# |    n_updates            | 9434          |
# |    policy_gradient_loss | -0.000598     |
# |    value_loss           | 4.93e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 844           |
# |    iterations           | 39            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00019520088 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.65e+07      |
# |    n_updates            | 9444          |
# |    policy_gradient_loss | -0.000311     |
# |    value_loss           | 5.23e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 40           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 3.903621e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.73e+07     |
# |    n_updates            | 9454         |
# |    policy_gradient_loss | -3.46e-05    |
# |    value_loss           | 5.56e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 848           |
# |    iterations           | 41            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 83968         |
# | train/                  |               |
# |    approx_kl            | 0.00016049642 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.94e+07      |
# |    n_updates            | 9464          |
# |    policy_gradient_loss | -7.65e-05     |
# |    value_loss           | 5.87e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 848           |
# |    iterations           | 42            |
# |    time_elapsed         | 101           |
# |    total_timesteps      | 86016         |
# | train/                  |               |
# |    approx_kl            | 0.00045557338 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.05e+07      |
# |    n_updates            | 9474          |
# |    policy_gradient_loss | -0.00165      |
# |    value_loss           | 6.18e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 849           |
# |    iterations           | 43            |
# |    time_elapsed         | 103           |
# |    total_timesteps      | 88064         |
# | train/                  |               |
# |    approx_kl            | 0.00024496458 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.24e+07      |
# |    n_updates            | 9484          |
# |    policy_gradient_loss | -0.000423     |
# |    value_loss           | 6.51e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 850           |
# |    iterations           | 44            |
# |    time_elapsed         | 105           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00047909532 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.41e+07      |
# |    n_updates            | 9494          |
# |    policy_gradient_loss | -0.000725     |
# |    value_loss           | 6.84e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 851           |
# |    iterations           | 45            |
# |    time_elapsed         | 108           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00026814514 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.59e+07      |
# |    n_updates            | 9504          |
# |    policy_gradient_loss | -0.000376     |
# |    value_loss           | 7.2e+07       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 850           |
# |    iterations           | 46            |
# |    time_elapsed         | 110           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00017850727 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.71e+07      |
# |    n_updates            | 9514          |
# |    policy_gradient_loss | -0.000161     |
# |    value_loss           | 7.56e+07      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 47          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.000982054 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 2.38e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.01e+07    |
# |    n_updates            | 9524        |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 7.94e+07    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 854           |
# |    iterations           | 48            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 0.00037106228 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.21e+07      |
# |    n_updates            | 9534          |
# |    policy_gradient_loss | -0.000776     |
# |    value_loss           | 8.34e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 850           |
# |    iterations           | 49            |
# |    time_elapsed         | 117           |
# |    total_timesteps      | 100352        |
# | train/                  |               |
# |    approx_kl            | 0.00055531645 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.5          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.34e+07      |
# |    n_updates            | 9544          |
# |    policy_gradient_loss | -0.00114      |
# |    value_loss           | 8.74e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 50           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0001149243 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.53e+07     |
# |    n_updates            | 9554         |
# |    policy_gradient_loss | -0.000237    |
# |    value_loss           | 9.15e+07     |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 852            |
# |    iterations           | 51             |
# |    time_elapsed         | 122            |
# |    total_timesteps      | 104448         |
# | train/                  |                |
# |    approx_kl            | 0.000106250896 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.51          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 4.83e+07       |
# |    n_updates            | 9564           |
# |    policy_gradient_loss | -0.000334      |
# |    value_loss           | 9.57e+07       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 857           |
# |    iterations           | 52            |
# |    time_elapsed         | 124           |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 0.00013330611 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.99e+07      |
# |    n_updates            | 9574          |
# |    policy_gradient_loss | -0.000246     |
# |    value_loss           | 1e+08         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 53           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0001411752 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.25e+07     |
# |    n_updates            | 9584         |
# |    policy_gradient_loss | -0.000174    |
# |    value_loss           | 1.05e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 54           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0004389109 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.5e+07      |
# |    n_updates            | 9594         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 1.09e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 870           |
# |    iterations           | 55            |
# |    time_elapsed         | 129           |
# |    total_timesteps      | 112640        |
# | train/                  |               |
# |    approx_kl            | 0.00024574337 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.67e+07      |
# |    n_updates            | 9604          |
# |    policy_gradient_loss | -0.00047      |
# |    value_loss           | 1.14e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 875           |
# |    iterations           | 56            |
# |    time_elapsed         | 130           |
# |    total_timesteps      | 114688        |
# | train/                  |               |
# |    approx_kl            | 0.00012304544 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.93e+07      |
# |    n_updates            | 9614          |
# |    policy_gradient_loss | -0.000189     |
# |    value_loss           | 1.18e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 877           |
# |    iterations           | 57            |
# |    time_elapsed         | 133           |
# |    total_timesteps      | 116736        |
# | train/                  |               |
# |    approx_kl            | 0.00013560898 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.17e+07      |
# |    n_updates            | 9624          |
# |    policy_gradient_loss | -0.000413     |
# |    value_loss           | 1.23e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 877           |
# |    iterations           | 58            |
# |    time_elapsed         | 135           |
# |    total_timesteps      | 118784        |
# | train/                  |               |
# |    approx_kl            | 0.00012538495 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.42e+07      |
# |    n_updates            | 9634          |
# |    policy_gradient_loss | -0.000141     |
# |    value_loss           | 1.27e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 878           |
# |    iterations           | 59            |
# |    time_elapsed         | 137           |
# |    total_timesteps      | 120832        |
# | train/                  |               |
# |    approx_kl            | 7.0398266e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.66e+07      |
# |    n_updates            | 9644          |
# |    policy_gradient_loss | -0.00023      |
# |    value_loss           | 1.32e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 879           |
# |    iterations           | 60            |
# |    time_elapsed         | 139           |
# |    total_timesteps      | 122880        |
# | train/                  |               |
# |    approx_kl            | 0.00072464405 |
# |    clip_fraction        | 0.000635      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.88e+07      |
# |    n_updates            | 9654          |
# |    policy_gradient_loss | -0.000445     |
# |    value_loss           | 1.37e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 880           |
# |    iterations           | 61            |
# |    time_elapsed         | 141           |
# |    total_timesteps      | 124928        |
# | train/                  |               |
# |    approx_kl            | 3.7578488e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.09e+07      |
# |    n_updates            | 9664          |
# |    policy_gradient_loss | -0.000112     |
# |    value_loss           | 1.41e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 880           |
# |    iterations           | 62            |
# |    time_elapsed         | 144           |
# |    total_timesteps      | 126976        |
# | train/                  |               |
# |    approx_kl            | 0.00060140016 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.38e+07      |
# |    n_updates            | 9674          |
# |    policy_gradient_loss | -0.000598     |
# |    value_loss           | 1.46e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 880          |
# ...
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.42e+08      |
# |    n_updates            | 10504         |
# |    policy_gradient_loss | -0.000298     |
# |    value_loss           | 8.77e+08      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 146         |
# |    time_elapsed         | 309         |
# |    total_timesteps      | 299008      |
# | train/                  |             |
# |    approx_kl            | 5.63683e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.5e+08     |
# |    n_updates            | 10514       |
# |    policy_gradient_loss | -3.3e-05    |
# |    value_loss           | 8.9e+08     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 963           |
# |    iterations           | 147           |
# |    time_elapsed         | 312           |
# |    total_timesteps      | 301056        |
# | train/                  |               |
# |    approx_kl            | 9.5334835e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.52e+08      |
# |    n_updates            | 10524         |
# |    policy_gradient_loss | -5.18e-05     |
# |    value_loss           | 9.03e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 964          |
# |    iterations           | 148          |
# |    time_elapsed         | 314          |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 1.194299e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.55e+08     |
# |    n_updates            | 10534        |
# |    policy_gradient_loss | -3.17e-05    |
# |    value_loss           | 9.16e+08     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 965           |
# |    iterations           | 149           |
# |    time_elapsed         | 316           |
# |    total_timesteps      | 305152        |
# | train/                  |               |
# |    approx_kl            | 0.00018108811 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.67e+08      |
# |    n_updates            | 10544         |
# |    policy_gradient_loss | -0.000951     |
# |    value_loss           | 9.29e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 966           |
# |    iterations           | 150           |
# |    time_elapsed         | 317           |
# |    total_timesteps      | 307200        |
# | train/                  |               |
# |    approx_kl            | 7.7310135e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.67e+08      |
# |    n_updates            | 10554         |
# |    policy_gradient_loss | -2.71e-05     |
# |    value_loss           | 9.42e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 967           |
# |    iterations           | 151           |
# |    time_elapsed         | 319           |
# |    total_timesteps      | 309248        |
# | train/                  |               |
# |    approx_kl            | 1.7915154e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.8e+08       |
# |    n_updates            | 10564         |
# |    policy_gradient_loss | -1.3e-05      |
# |    value_loss           | 9.55e+08      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 969           |
# |    iterations           | 152           |
# |    time_elapsed         | 321           |
# |    total_timesteps      | 311296        |
# | train/                  |               |
# |    approx_kl            | 1.6558886e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.89e+08      |
# |    n_updates            | 10574         |
# |    policy_gradient_loss | -5.99e-05     |
# |    value_loss           | 9.69e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 970          |
# |    iterations           | 153          |
# |    time_elapsed         | 322          |
# |    total_timesteps      | 313344       |
# | train/                  |              |
# |    approx_kl            | 9.121286e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.96e+08     |
# |    n_updates            | 10584        |
# |    policy_gradient_loss | -0.000107    |
# |    value_loss           | 9.82e+08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 971         |
# |    iterations           | 154         |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 315392      |
# | train/                  |             |
# |    approx_kl            | 6.86929e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.96e+08    |
# |    n_updates            | 10594       |
# |    policy_gradient_loss | -3.07e-06   |
# |    value_loss           | 9.95e+08    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 972           |
# |    iterations           | 155           |
# |    time_elapsed         | 326           |
# |    total_timesteps      | 317440        |
# | train/                  |               |
# |    approx_kl            | 0.00024094514 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.95e+08      |
# |    n_updates            | 10604         |
# |    policy_gradient_loss | -0.000272     |
# |    value_loss           | 1.01e+09      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 973          |
# |    iterations           | 156          |
# |    time_elapsed         | 328          |
# |    total_timesteps      | 319488       |
# | train/                  |              |
# |    approx_kl            | 5.350972e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.11e+08     |
# |    n_updates            | 10614        |
# |    policy_gradient_loss | -3.77e-05    |
# |    value_loss           | 1.02e+09     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 973          |
# |    iterations           | 157          |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 321536       |
# | train/                  |              |
# |    approx_kl            | 4.931522e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.2e+08      |
# |    n_updates            | 10624        |
# |    policy_gradient_loss | -0.000244    |
# |    value_loss           | 1.04e+09     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 974          |
# |    iterations           | 158          |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 323584       |
# | train/                  |              |
# |    approx_kl            | 6.130224e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.27e+08     |
# |    n_updates            | 10634        |
# |    policy_gradient_loss | -0.00105     |
# |    value_loss           | 1.05e+09     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 974           |
# |    iterations           | 159           |
# |    time_elapsed         | 333           |
# |    total_timesteps      | 325632        |
# | train/                  |               |
# |    approx_kl            | 2.4765002e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.32e+08      |
# |    n_updates            | 10644         |
# |    policy_gradient_loss | -0.000174     |
# |    value_loss           | 1.06e+09      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 975           |
# |    iterations           | 160           |
# |    time_elapsed         | 336           |
# |    total_timesteps      | 327680        |
# | train/                  |               |
# |    approx_kl            | 1.5112018e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.51         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.28e+08      |
# |    n_updates            | 10654         |
# |    policy_gradient_loss | -9.01e-05     |
# |    value_loss           | 1.08e+09      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 974           |
# |    iterations           | 161           |
# |    time_elapsed         | 338           |
# |    total_timesteps      | 329728        |
# | train/                  |               |
# |    approx_kl            | 1.1625612e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.39e+08      |
# |    n_updates            | 10664         |
# |    policy_gradient_loss | -7.01e-05     |
# |    value_loss           | 1.09e+09      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 975           |
# |    iterations           | 162           |
# |    time_elapsed         | 340           |
# |    total_timesteps      | 331776        |
# | train/                  |               |
# |    approx_kl            | 0.00021841849 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.52         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.72e+08      |
# |    n_updates            | 10674         |
# |    policy_gradient_loss | -0.0012       |
# |    value_loss           | 7.98e+08      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 163         |
# |    time_elapsed         | 342         |
# |    total_timesteps      | 333824      |
# | train/                  |             |
# |    approx_kl            | 0.009735011 |
# |    clip_fraction        | 0.0083      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.47e+05    |
# |    n_updates            | 10684       |
# |    policy_gradient_loss | -0.00396    |
# |    value_loss           | 8.92e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 974          |
# |    iterations           | 164          |
# |    time_elapsed         | 344          |
# |    total_timesteps      | 335872       |
# | train/                  |              |
# |    approx_kl            | 0.0071929707 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.79e+05     |
# |    n_updates            | 10694        |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 5.66e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 974         |
# |    iterations           | 165         |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 337920      |
# | train/                  |             |
# |    approx_kl            | 0.010239495 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51e+05    |
# |    n_updates            | 10704       |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 3.08e+05    |
# -----------------------------------------
# Training Interrupted
# Saving Model

# %%
# env.close()

# %%
# Evaluate the model
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=1)
print(f"Mean Reward: {mean_reward}, Std Reward: {std_reward}")
# Out:
# Mean Reward: 0.48489999771118164, Std Reward: 0.0

# %%
def make_env():
    def _init():
        env = IntelliGoal()
        env.render_mode = 'human'
        return env
    return _init

# Wrap your environment in a DummyVecEnv for compatibility
env = DummyVecEnv([make_env()])

model = PPO.load(save_path, env=env, device=device)

def run_model():
    obs = env.reset()  # This will now be in the correct batch format
    done = False
    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, rewards, done, info = env.step(action)
        env.render()
        if done:
            obs = env.reset()

try:
    run_model()
except KeyboardInterrupt:
    print("Environment Closed")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[25], line 24
#      21             obs = env.reset()
#      23 try:
# ---> 24     run_model()
#      25 except KeyboardInterrupt:
#      26     print("Environment Closed")
#
# Cell In[25], line 19, in run_model()
#      17 action, _states = model.predict(obs, deterministic=True)
#      18 obs, rewards, done, info = env.step(action)
# ---> 19 env.render()
#      20 if done:
#      21     obs = env.reset()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:103, in DummyVecEnv.render(self, mode)
#      96 def render(self, mode: Optional[str] = None) -> Optional[np.ndarray]:
#      97     """
#      98     Gym environment rendering. If there are multiple environments then
#      99     they are tiled together in one image via ``BaseVecEnv.render()``.
#     100
#     101     :param mode: The rendering type.
#     102     """
# --> 103     return super().render(mode=mode)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:250, in VecEnv.render(self, mode)
#     246 # mode == self.render_mode == "human"
#     247 # In that case, we try to call `self.env.render()` but it might
#     248 # crash for subprocesses
#     249 if self.render_mode == "human":
# --> 250     self.env_method("render")
#     251     return None
#     253 if mode == "rgb_array" or mode == "human":
#     254     # call the render method of the environments
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:129, in DummyVecEnv.env_method(self, method_name, indices, *method_args, **method_kwargs)
#     127 """Call instance methods of vectorized environments."""
#     128 target_envs = self._get_target_envs(indices)
# --> 129 return [getattr(env_i, method_name)(*method_args, **method_kwargs) for env_i in target_envs]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:129, in <listcomp>(.0)
#     127 """Call instance methods of vectorized environments."""
#     128 target_envs = self._get_target_envs(indices)
# --> 129 return [getattr(env_i, method_name)(*method_args, **method_kwargs) for env_i in target_envs]
#
# Cell In[2], line 137, in IntelliGoal.render(s, mode)
#     134         pygame.quit()
#     135 s.player_x, s.player_y, s.goal_x, s.goal_y = s.state
# --> 137 s.screen.fill((0, 0, 0))
#     138 RED = (255, 0, 0)
#     139 BLUE = (0, 0, 255)
#
# error: display Surface quit
