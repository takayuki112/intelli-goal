# %%
import pygame
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import math
import random
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class IntelliGoal(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(s):
        super(IntelliGoal, s).__init__()
        
        s.screen_width = 1240
        s.screen_height = 800
        s.border_width = 10
        s.screen = None
        
        s.goal_radius = 20
        s.player_radius = 10
        
        s.player_speed = 1
        
        
        # State information
        s.player_x = 0
        s.player_y = 0
        s.goal_x = 0
        s.goal_y = 0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        s.reward = 0
        
        s.done = False
        s.trucated = False
        s.truncation_step_limit = 1000
        s.truncation_step_counter = 0
        s.goal_spawn_range = 300
        
        
        # State and Action spaces
        s.action_space = spaces.Discrete(5) # 0: No movement, 1: Up, 2: Down, 3: Left, 4: Right
        # observation space = [player_x, player_y, goal_x, goal_y]
        s.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 0]), 
            high=np.array([s.screen_width, s.screen_height, s.screen_width, s.screen_height]), 
            dtype=np.int32
        )
    
    def seed(s, seed=None):
        if seed is not None and (seed < 0 or seed >= 2**32):
            raise ValueError("Seed must be between 0 and 2**32 - 1")
        s.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]
        
    def reset(s, seed=0):
        s.seed(seed)
        
        s.player_x = s.screen_width // 2
        s.player_y = s.screen_height // 2
        
        s.goal_x, s.goal_y = s.respawn_goal()
        
        s.reward = 0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        
        s.done = False
        s.trucated = False
        s.truncation_step_counter = 0
        
        return s.state, {}
    
    def respawn_goal(s):
        s.goal_x = s.player_x + random.randint(-s.goal_spawn_range, s.goal_spawn_range)
        s.goal_y = s.player_y + random.randint(-s.goal_spawn_range, s.goal_spawn_range)
        
        # clip the goal to the screen
        offset = s.border_width + s.goal_radius
        s.goal_x = min( max(s.goal_x, offset), s.screen_width - offset)
        s.goal_y = min( max(s.goal_y, offset), s.screen_height - offset)
        
        pygame.time.wait(300)
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        return s.goal_x, s.goal_y
        
    def step(s, action):
        #################
        #do more here?
        #################
        
        s.reward = 0
        s.do_action(action)
        s.calculate_step_reward()
        
        s.truncation_step_counter += 1
        if s.truncation_step_counter >= s.truncation_step_limit:
            s.reward -= 1
            s.trucated = True
            s.done = True

        if s.reward < -1:
            # s.reward = -1
            s.trucated = True
        
        # if s.reward > 1:
        #     s.reward = 1
        
        
        return s.state, s.reward, s.done, s.trucated, {}
        
   
    def do_action(s, action):
        if not s.action_space.contains(action):
            print("Invalid Action")
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        s.player_x += (action == 4)*s.player_speed - (action == 3)*s.player_speed 
        s.player_y += (action == 2)*s.player_speed - (action == 1)*s.player_speed
        
    def calculate_step_reward(s):
        # Distance between player and goal
        distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)

        # Check if the red dot touches the border
        if s.player_x not in range(s.border_width, s.screen_width - s.border_width) or s.player_y not in range(s.border_width, s.screen_height - s.border_width):
            s.player_x, s.player_y = s.screen_width // 2, s.screen_height // 2
            s.reward = -1
            s.trucated = True
            s.done = True

        # Check if the goal is reached within a certain range
        if distance < s.goal_radius + s.player_radius:
            s.goal_x, s.goal_y = s.respawn_goal()
            s.reward += 1.5
            s.done = True  
    
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        # Reward the agent for getting closer to the goal
        if s.prev_distance > distance:
            s.reward = 0.5
        if s.prev_distance < distance:
            s.reward = -0.7
        
        # Penalize the agent for taking too long
        # s.reward -= 0.00008
     
    
    def keyboard_input(s):
        keys = pygame.key.get_pressed()
        # 1: Up, 2: Down, 3: Left, 4: Right
        if keys[pygame.K_UP]:
            return 1
        if keys[pygame.K_DOWN]:
            return 2
        if keys[pygame.K_LEFT]:
            return 3
        if keys[pygame.K_RIGHT]:
            return 4
        return 0
        
    
    def render(s, mode = 'human'):
        if s.screen == None:
            pygame.init()
            s.screen = pygame.display.set_mode((s.screen_width, s.screen_height))
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
        s.player_x, s.player_y, s.goal_x, s.goal_y = s.state
        
        s.screen.fill((0, 0, 0))
        RED = (255, 0, 0)
        BLUE = (0, 0, 255)
        BORDER_COLOR = (255, 255, 0)
        
        # Draw the border
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.border_width, s.screen_height))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, s.screen_height - s.border_width, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (s.screen_width - s.border_width, 0, s.border_width, s.screen_height))

        # Draw the red dot
        pygame.draw.circle(s.screen, RED, (s.player_x, s.player_y), 10)

        # Draw the blue dot
        pygame.draw.circle(s.screen, BLUE, (s.goal_x, s.goal_y), s.goal_radius)
        
        #Display Reward on pygame screen
        font = pygame.font.Font(None, 36)
        text = font.render("Reward: " + str(round(s.reward, 5)), True, (255, 255, 255))
        s.screen.blit(text, (10, 10))
        
        pygame.display.update()
    
    def close(s):
        pygame.quit()

# %%
# Test Env with keyboard input actions
test_env = IntelliGoal()
test_env.reset(0)
done = False
i = 1

# while True:
#     try:
#         test_env.render()
#         action = test_env.keyboard_input()
#         state, reward, done, truncated, _i = test_env.step(action)
#         if done or truncated:
#             print("Reward at step - ", i, " : ", round(reward, 5))
#             i += 1
#             test_env.reset(0)
#     except:
#         print("Environment Closed")
#         break

# while True:
#     test_env.render()
#     action = test_env.keyboard_input()
#     state, reward, done, truncated, _i = test_env.step(action)
#     if done or truncated:
#         print("Reward at step - ", i, " : ", round(reward, 5))
#         i += 1
#         test_env.reset(0)

# %% [markdown]
# # DQN Learning Algorithm

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
import torch
device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
    print("Using GPU - ", torch.cuda.get_device_name(0))
# Out:
# Using GPU -  NVIDIA RTX A500 Laptop GPU

# %%
env = IntelliGoal()
check_env(env)

# %%
def make_env():
    env = IntelliGoal()
    return env

num_envs = 4
take_logs = False
device = "cuda"

if take_logs:
    log_dir = "./logs/ppo_intelligoal_a3_explore-more"
else:
    log_dir = None
      
if num_envs == 1:
    env = DummyVecEnv([make_env] * num_envs)
else:
    env = SubprocVecEnv([make_env] * num_envs)


# model = PPO("MlpPolicy", env, verbose=1, device=device)

# Define DQN model with specific parameters
model = DQN("MlpPolicy", env, verbose=1, 
            buffer_size=10000, 
            learning_rate=0.001, 
            batch_size=64, 
            tau=1.0, 
            gamma=0.99, 
            train_freq=4, 
            gradient_steps=1, 
            exploration_fraction=0.5,
            exploration_initial_eps=1.0, 
            exploration_final_eps=0.01, 
            target_update_interval=500, 
            max_grad_norm=10, 
            tensorboard_log="./logs/dqn_intelligoal_tensorboard/", 
            device=device)
# Out:
# Using cuda device

# %%
# Start New training session
save_path = "./models/intelli_goal_a7"

# if os.path.exists(save_path +".zip"):
#     #append number to the file name
#     i = save_path[-1]
#     i = int(i) + 1
#     save_path = save_path[:-1] + str(i)
#     print("Model already exists. Saving new one as - ", save_path)
    
try:
    model.learn(total_timesteps=9999999999)
    model.save(save_path)
except KeyboardInterrupt:
    print("Training Interrupted")
    model.save(save_path)
# Out:
# Logging to ./logs/dqn_intelligoal_tensorboard/DQN_9
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1083     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.172    |
# |    n_updates        | 487      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1191     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0956   |
# |    n_updates        | 987      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1185     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.15     |
# |    n_updates        | 1487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1183     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0703   |
# |    n_updates        | 1987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1207     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0685   |
# |    n_updates        | 2487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1226     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.28     |
# |    n_updates        | 2987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1220     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 28000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.09     |
# |    n_updates        | 3487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1213     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 32000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.225    |
# |    n_updates        | 3987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1222     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0504   |
# |    n_updates        | 4487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1234     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 40000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0462   |
# |    n_updates        | 4987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1236     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 44000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0529   |
# |    n_updates        | 5487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1231     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 48000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0786   |
# |    n_updates        | 5987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1232     |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 52000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.135    |
# |    n_updates        | 6487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1239     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 56000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0665   |
# |    n_updates        | 6987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1243     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0545   |
# |    n_updates        | 7487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1238     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 64000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0965   |
# |    n_updates        | 7987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1234     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 68000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0856   |
# |    n_updates        | 8487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1240     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 72000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0207   |
# |    n_updates        | 8987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1245     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 76000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0441   |
# |    n_updates        | 9487     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1241     |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 80000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0269   |
# |    n_updates        | 9987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1220     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 84000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0256   |
# |    n_updates        | 10487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1213     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 88000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0278   |
# |    n_updates        | 10987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1208     |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 92000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0441   |
# |    n_updates        | 11487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1197     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 96000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0141   |
# |    n_updates        | 11987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1187     |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 100000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0108   |
# |    n_updates        | 12487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1180     |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 104000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0265   |
# |    n_updates        | 12987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1178     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 108000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0173   |
# |    n_updates        | 13487    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1173     |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 112000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00766  |
# |    n_updates        | 13987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1159     |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 115322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0148   |
# |    n_updates        | 14403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1152     |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 119322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00536  |
# |    n_updates        | 14903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1150     |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 123322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00619  |
# |    n_updates        | 15403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1149     |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 127322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0111   |
# |    n_updates        | 15903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1143     |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 131322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00572  |
# |    n_updates        | 16403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1138     |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 135322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00769  |
# |    n_updates        | 16903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1137     |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 139322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0113   |
# |    n_updates        | 17403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1136     |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 143322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00763  |
# |    n_updates        | 17903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1133     |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 147322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00842  |
# |    n_updates        | 18403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1129     |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 151322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00736  |
# |    n_updates        | 18903    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1126     |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 155322   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00599  |
# |    n_updates        | 19403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1120     |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 158000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00486  |
# |    n_updates        | 19737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1120     |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 162000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0105   |
# |    n_updates        | 20237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1116     |
# |    time_elapsed     | 148      |
# |    total_timesteps  | 166000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00399  |
# |    n_updates        | 20737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1113     |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 170000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00299  |
# |    n_updates        | 21237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1113     |
# |    time_elapsed     | 156      |
# |    total_timesteps  | 174000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00525  |
# |    n_updates        | 21737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1112     |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 178000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00497  |
# |    n_updates        | 22237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1109     |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 182000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0104   |
# |    n_updates        | 22737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1106     |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 186000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00497  |
# |    n_updates        | 23237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1105     |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 190000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00648  |
# |    n_updates        | 23737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1105     |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 194000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00474  |
# |    n_updates        | 24237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1104     |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 198000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0849   |
# |    n_updates        | 24737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1101     |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 202000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00457  |
# |    n_updates        | 25237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1100     |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 206000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00628  |
# |    n_updates        | 25737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1100     |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 210000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0248   |
# |    n_updates        | 26237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1100     |
# |    time_elapsed     | 194      |
# |    total_timesteps  | 214000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00631  |
# |    n_updates        | 26737    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1098     |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 218000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.01     |
# |    n_updates        | 27237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1093     |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 221566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00679  |
# |    n_updates        | 27683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1090     |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 224496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00492  |
# |    n_updates        | 28049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1090     |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 228496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00444  |
# |    n_updates        | 28549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1089     |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 232496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00362  |
# |    n_updates        | 29049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1088     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 236496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00288  |
# |    n_updates        | 29549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1087     |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 240496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00521  |
# |    n_updates        | 30049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1087     |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 244496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00264  |
# |    n_updates        | 30549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1087     |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 248496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00493  |
# |    n_updates        | 31049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1085     |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 252496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00476  |
# |    n_updates        | 31549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1084     |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 256496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00403  |
# |    n_updates        | 32049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1084     |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 260496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00348  |
# |    n_updates        | 32549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1085     |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 264496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00917  |
# |    n_updates        | 33049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1083     |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 268496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00267  |
# |    n_updates        | 33549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1082     |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 272496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0205   |
# |    n_updates        | 34049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1081     |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 276496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00249  |
# |    n_updates        | 34549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1080     |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 280496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0112   |
# |    n_updates        | 35049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1078     |
# |    time_elapsed     | 263      |
# |    total_timesteps  | 284496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0471   |
# |    n_updates        | 35549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1077     |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 288496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00287  |
# |    n_updates        | 36049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1077     |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 292496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00362  |
# |    n_updates        | 36549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1076     |
# |    time_elapsed     | 275      |
# |    total_timesteps  | 296496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0167   |
# |    n_updates        | 37049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1074     |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 300496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00379  |
# |    n_updates        | 37549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1073     |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 304496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00701  |
# |    n_updates        | 38049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1073     |
# |    time_elapsed     | 287      |
# |    total_timesteps  | 308496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0485   |
# |    n_updates        | 38549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1073     |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 312496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0104   |
# |    n_updates        | 39049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1073     |
# |    time_elapsed     | 294      |
# |    total_timesteps  | 316496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0331   |
# |    n_updates        | 39549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1072     |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 320496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00498  |
# |    n_updates        | 40049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1071     |
# |    time_elapsed     | 302      |
# |    total_timesteps  | 324496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00646  |
# |    n_updates        | 40549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1071     |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 328496   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.024    |
# |    n_updates        | 41049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1070     |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 331690   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00892  |
# |    n_updates        | 41449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1068     |
# |    time_elapsed     | 314      |
# |    total_timesteps  | 335690   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00646  |
# |    n_updates        | 41949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1067     |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 339690   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0107   |
# |    n_updates        | 42449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1067     |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 343690   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00893  |
# |    n_updates        | 42949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1068     |
# |    time_elapsed     | 325      |
# |    total_timesteps  | 347690   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00477  |
# |    n_updates        | 43449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1067     |
# |    time_elapsed     | 329      |
# |    total_timesteps  | 351690   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00283  |
# |    n_updates        | 43949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1066     |
# |    time_elapsed     | 333      |
# |    total_timesteps  | 355690   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00437  |
# |    n_updates        | 44449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1065     |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 359566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00765  |
# |    n_updates        | 44933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1065     |
# |    time_elapsed     | 341      |
# |    total_timesteps  | 363566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0166   |
# |    n_updates        | 45433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1065     |
# |    time_elapsed     | 345      |
# |    total_timesteps  | 367566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.026    |
# |    n_updates        | 45933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1064     |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 371566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00776  |
# |    n_updates        | 46433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1063     |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 375566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.015    |
# |    n_updates        | 46933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1064     |
# |    time_elapsed     | 356      |
# |    total_timesteps  | 379566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0144   |
# |    n_updates        | 47433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1064     |
# |    time_elapsed     | 360      |
# |    total_timesteps  | 383566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00368  |
# |    n_updates        | 47933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1063     |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 387566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0112   |
# |    n_updates        | 48433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1062     |
# |    time_elapsed     | 368      |
# |    total_timesteps  | 391566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0254   |
# |    n_updates        | 48933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1062     |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 395566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0259   |
# |    n_updates        | 49433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1062     |
# |    time_elapsed     | 375      |
# |    total_timesteps  | 399566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0107   |
# |    n_updates        | 49933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1061     |
# |    time_elapsed     | 380      |
# |    total_timesteps  | 403566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00759  |
# |    n_updates        | 50433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1060     |
# |    time_elapsed     | 384      |
# |    total_timesteps  | 407566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00564  |
# |    n_updates        | 50933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1061     |
# |    time_elapsed     | 387      |
# |    total_timesteps  | 411566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00807  |
# |    n_updates        | 51433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1060     |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 415566   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0189   |
# |    n_updates        | 51933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 1035     |
# |    time_elapsed     | 1103     |
# |    total_timesteps  | 1143228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00363  |
# |    n_updates        | 142891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 1035     |
# |    time_elapsed     | 1107     |
# |    total_timesteps  | 1147228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00527  |
# |    n_updates        | 143391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 1035     |
# |    time_elapsed     | 1111     |
# |    total_timesteps  | 1151228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0732   |
# |    n_updates        | 143891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 1035     |
# |    time_elapsed     | 1115     |
# |    total_timesteps  | 1155228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00515  |
# |    n_updates        | 144391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 1035     |
# |    time_elapsed     | 1119     |
# |    total_timesteps  | 1159228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00578  |
# |    n_updates        | 144891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 1035     |
# |    time_elapsed     | 1123     |
# |    total_timesteps  | 1163228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00441  |
# |    n_updates        | 145391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 1035     |
# |    time_elapsed     | 1127     |
# |    total_timesteps  | 1167228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0107   |
# |    n_updates        | 145891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 1035     |
# |    time_elapsed     | 1131     |
# |    total_timesteps  | 1171228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00525  |
# |    n_updates        | 146391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 1035     |
# |    time_elapsed     | 1135     |
# |    total_timesteps  | 1175228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00559  |
# |    n_updates        | 146891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 1035     |
# |    time_elapsed     | 1139     |
# |    total_timesteps  | 1179228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00602  |
# |    n_updates        | 147391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 1035     |
# |    time_elapsed     | 1143     |
# |    total_timesteps  | 1183228  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00692  |
# |    n_updates        | 147891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 1034     |
# |    time_elapsed     | 1146     |
# |    total_timesteps  | 1186248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00648  |
# |    n_updates        | 148268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 1034     |
# |    time_elapsed     | 1150     |
# |    total_timesteps  | 1190248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0089   |
# |    n_updates        | 148768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 1034     |
# |    time_elapsed     | 1154     |
# |    total_timesteps  | 1194248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00499  |
# |    n_updates        | 149268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 1034     |
# |    time_elapsed     | 1158     |
# |    total_timesteps  | 1198248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00601  |
# |    n_updates        | 149768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 1034     |
# |    time_elapsed     | 1162     |
# |    total_timesteps  | 1202248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0102   |
# |    n_updates        | 150268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 1034     |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 1206248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00696  |
# |    n_updates        | 150768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 1033     |
# |    time_elapsed     | 1170     |
# |    total_timesteps  | 1210248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00603  |
# |    n_updates        | 151268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 1033     |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 1214248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0064   |
# |    n_updates        | 151768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 1033     |
# |    time_elapsed     | 1179     |
# |    total_timesteps  | 1218248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0109   |
# |    n_updates        | 152268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 1032     |
# |    time_elapsed     | 1183     |
# |    total_timesteps  | 1222248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00494  |
# |    n_updates        | 152768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 1032     |
# |    time_elapsed     | 1187     |
# |    total_timesteps  | 1226248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00563  |
# |    n_updates        | 153268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 1032     |
# |    time_elapsed     | 1191     |
# |    total_timesteps  | 1230248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00658  |
# |    n_updates        | 153768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 1032     |
# |    time_elapsed     | 1195     |
# |    total_timesteps  | 1234248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0324   |
# |    n_updates        | 154268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 1032     |
# |    time_elapsed     | 1199     |
# |    total_timesteps  | 1238248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.007    |
# |    n_updates        | 154768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 1032     |
# |    time_elapsed     | 1203     |
# |    total_timesteps  | 1242248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00466  |
# |    n_updates        | 155268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 1032     |
# |    time_elapsed     | 1207     |
# |    total_timesteps  | 1246248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00348  |
# |    n_updates        | 155768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 1032     |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 1250248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0116   |
# |    n_updates        | 156268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 1032     |
# |    time_elapsed     | 1215     |
# |    total_timesteps  | 1254248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00631  |
# |    n_updates        | 156768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 1031     |
# |    time_elapsed     | 1219     |
# |    total_timesteps  | 1258248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0104   |
# |    n_updates        | 157268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 1031     |
# |    time_elapsed     | 1224     |
# |    total_timesteps  | 1262248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00668  |
# |    n_updates        | 157768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 1030     |
# |    time_elapsed     | 1228     |
# |    total_timesteps  | 1266248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00394  |
# |    n_updates        | 158268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 1030     |
# |    time_elapsed     | 1232     |
# |    total_timesteps  | 1270248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00306  |
# |    n_updates        | 158768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 1030     |
# |    time_elapsed     | 1236     |
# |    total_timesteps  | 1274248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00838  |
# |    n_updates        | 159268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 1030     |
# |    time_elapsed     | 1240     |
# |    total_timesteps  | 1278248  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00648  |
# |    n_updates        | 159768   |
# ----------------------------------
# Training Interrupted

# %%
def make_env():
    env = IntelliGoal()
    return env

num_envs = 2
take_logs = False
device = "cuda"

if take_logs:
    log_dir = "./logs/ppo_intelligoal_a3_explore-more"
else:
    log_dir = None
      
if num_envs == 1:
    env = DummyVecEnv([make_env] * num_envs)
else:
    env = SubprocVecEnv([make_env] * num_envs)

# %%
# Load and resume training from saved model
try:
    model.load(path = save_path, env = env)
    model.learn(total_timesteps=100000000, reset_num_timesteps=False, progress_bar=False)
    model.save(save_path)
except KeyboardInterrupt:
    print("Training Interrupted")
    print("Saving Model")
    model.save(save_path)
# Out:
# Logging to ./logs/dqn_intelligoal_tensorboard/DQN_9
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 602      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1282488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00216  |
# |    n_updates        | 160797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 603      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 1286488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0494   |
# |    n_updates        | 161797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 1304     |
# |    fps              | 611      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 1290488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00544  |
# |    n_updates        | 162797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 1308     |
# |    fps              | 610      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 1294488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.008    |
# |    n_updates        | 163797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 1312     |
# |    fps              | 614      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1298488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0549   |
# |    n_updates        | 164797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 1316     |
# |    fps              | 616      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 1302488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00691  |
# |    n_updates        | 165797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 615      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 1306488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00422  |
# |    n_updates        | 166797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 1324     |
# |    fps              | 616      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 1310488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00475  |
# |    n_updates        | 167797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 1328     |
# |    fps              | 617      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 1314488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00437  |
# |    n_updates        | 168797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 1332     |
# |    fps              | 618      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 1318488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0062   |
# |    n_updates        | 169797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 1336     |
# |    fps              | 618      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 1322488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0941   |
# |    n_updates        | 170797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 619      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 1326488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.107    |
# |    n_updates        | 171797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 1344     |
# |    fps              | 619      |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 1330488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00701  |
# |    n_updates        | 172797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 1348     |
# |    fps              | 620      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 1334488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00515  |
# |    n_updates        | 173797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 1352     |
# |    fps              | 620      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 1338488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00443  |
# |    n_updates        | 174797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 1356     |
# |    fps              | 622      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 1342488  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0046   |
# |    n_updates        | 175797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 618      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 1345489  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00625  |
# |    n_updates        | 176548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 620      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 1349489  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00484  |
# |    n_updates        | 177548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 620      |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 1353489  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00375  |
# |    n_updates        | 178548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 621      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 1357489  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0057   |
# |    n_updates        | 179548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 622      |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 1361489  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00651  |
# |    n_updates        | 180548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 622      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 1365489  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00521  |
# |    n_updates        | 181548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 623      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 1369489  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00551  |
# |    n_updates        | 182548   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 621      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 1372532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00324  |
# |    n_updates        | 183308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 620      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 1376532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00568  |
# |    n_updates        | 184308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 620      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 1380532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00647  |
# |    n_updates        | 185308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 621      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 1384532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00498  |
# |    n_updates        | 186308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 621      |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 1388532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00463  |
# |    n_updates        | 187308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 622      |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 1392532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0047   |
# |    n_updates        | 188308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 622      |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 1396532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00367  |
# |    n_updates        | 189308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 622      |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 1400532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0879   |
# |    n_updates        | 190308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 622      |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 1404532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00404  |
# |    n_updates        | 191308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 623      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 1408532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00477  |
# |    n_updates        | 192308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 623      |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 1412532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00535  |
# |    n_updates        | 193308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 623      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 1416532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00433  |
# |    n_updates        | 194308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 623      |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 1420532  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00512  |
# |    n_updates        | 195308   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 621      |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 1423533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00295  |
# |    n_updates        | 196059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 621      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 1427533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00624  |
# |    n_updates        | 197059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 621      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 1431533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00272  |
# |    n_updates        | 198059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 621      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 1435533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00419  |
# |    n_updates        | 199059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 620      |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 1439533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00443  |
# |    n_updates        | 200059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 620      |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 1443533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00482  |
# |    n_updates        | 201059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 1464     |
# |    fps              | 619      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 1447533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00457  |
# |    n_updates        | 202059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 619      |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 1451533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00479  |
# |    n_updates        | 203059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 619      |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 1455533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00497  |
# |    n_updates        | 204059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 619      |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 1459533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0481   |
# |    n_updates        | 205059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 619      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 1463533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00444  |
# |    n_updates        | 206059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 1484     |
# |    fps              | 619      |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 1467533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0054   |
# |    n_updates        | 207059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 1488     |
# |    fps              | 619      |
# |    time_elapsed     | 311      |
# |    total_timesteps  | 1471533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00302  |
# |    n_updates        | 208059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 1492     |
# |    fps              | 618      |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 1475533  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00639  |
# |    n_updates        | 209059   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 1496     |
# |    fps              | 617      |
# |    time_elapsed     | 323      |
# |    total_timesteps  | 1478534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00423  |
# |    n_updates        | 209809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 617      |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 1482534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00396  |
# |    n_updates        | 210809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 1504     |
# |    fps              | 617      |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 1486534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00442  |
# |    n_updates        | 211809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 1508     |
# |    fps              | 617      |
# |    time_elapsed     | 343      |
# |    total_timesteps  | 1490534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00871  |
# |    n_updates        | 212809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 1512     |
# |    fps              | 617      |
# |    time_elapsed     | 349      |
# |    total_timesteps  | 1494534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00608  |
# |    n_updates        | 213809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 1516     |
# |    fps              | 617      |
# |    time_elapsed     | 356      |
# |    total_timesteps  | 1498534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00397  |
# |    n_updates        | 214809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 618      |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 1502534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00319  |
# |    n_updates        | 215809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 1524     |
# |    fps              | 618      |
# |    time_elapsed     | 368      |
# |    total_timesteps  | 1506534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00452  |
# |    n_updates        | 216809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 1528     |
# |    fps              | 618      |
# |    time_elapsed     | 375      |
# |    total_timesteps  | 1510534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00422  |
# |    n_updates        | 217809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 1532     |
# |    fps              | 618      |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 1514534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00412  |
# |    n_updates        | 218809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 1536     |
# |    fps              | 618      |
# |    time_elapsed     | 388      |
# |    total_timesteps  | 1518534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00318  |
# |    n_updates        | 219809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 618      |
# |    time_elapsed     | 394      |
# |    total_timesteps  | 1522534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0109   |
# |    n_updates        | 220809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 1544     |
# |    fps              | 618      |
# |    time_elapsed     | 400      |
# |    total_timesteps  | 1526534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00321  |
# |    n_updates        | 221809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 1548     |
# |    fps              | 618      |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 1530534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00528  |
# |    n_updates        | 222809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 1552     |
# |    fps              | 618      |
# |    time_elapsed     | 413      |
# |    total_timesteps  | 1534534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00448  |
# |    n_updates        | 223809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 1556     |
# |    fps              | 619      |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 1538534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00364  |
# |    n_updates        | 224809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 619      |
# |    time_elapsed     | 426      |
# |    total_timesteps  | 1542534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.147    |
# |    n_updates        | 225809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 1564     |
# |    fps              | 619      |
# |    time_elapsed     | 432      |
# |    total_timesteps  | 1546534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0036   |
# |    n_updates        | 226809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 1568     |
# |    fps              | 619      |
# |    time_elapsed     | 439      |
# |    total_timesteps  | 1550534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00384  |
# |    n_updates        | 227809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 619      |
# |    time_elapsed     | 445      |
# |    total_timesteps  | 1554534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00296  |
# |    n_updates        | 228809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 619      |
# |    time_elapsed     | 452      |
# |    total_timesteps  | 1558534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00924  |
# |    n_updates        | 229809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 619      |
# |    time_elapsed     | 458      |
# |    total_timesteps  | 1562534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00474  |
# |    n_updates        | 230809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 1584     |
# |    fps              | 619      |
# |    time_elapsed     | 464      |
# |    total_timesteps  | 1566534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00598  |
# |    n_updates        | 231809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 1588     |
# |    fps              | 619      |
# |    time_elapsed     | 471      |
# |    total_timesteps  | 1570534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00566  |
# |    n_updates        | 232809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 1592     |
# |    fps              | 619      |
# |    time_elapsed     | 477      |
# |    total_timesteps  | 1574534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.114    |
# |    n_updates        | 233809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 1596     |
# |    fps              | 619      |
# |    time_elapsed     | 484      |
# |    total_timesteps  | 1578534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00264  |
# |    n_updates        | 234809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 619      |
# |    time_elapsed     | 490      |
# |    total_timesteps  | 1582534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00495  |
# |    n_updates        | 235809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 1604     |
# |    fps              | 619      |
# |    time_elapsed     | 497      |
# |    total_timesteps  | 1586534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00515  |
# |    n_updates        | 236809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 1608     |
# |    fps              | 619      |
# |    time_elapsed     | 504      |
# |    total_timesteps  | 1590534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00653  |
# |    n_updates        | 237809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 1612     |
# |    fps              | 618      |
# |    time_elapsed     | 510      |
# |    total_timesteps  | 1594534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00937  |
# |    n_updates        | 238809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 1616     |
# |    fps              | 618      |
# |    time_elapsed     | 517      |
# |    total_timesteps  | 1598534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00402  |
# |    n_updates        | 239809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 1620     |
# |    fps              | 618      |
# |    time_elapsed     | 523      |
# |    total_timesteps  | 1602534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00636  |
# |    n_updates        | 240809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 1624     |
# |    fps              | 618      |
# |    time_elapsed     | 530      |
# |    total_timesteps  | 1606534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00485  |
# |    n_updates        | 241809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 1628     |
# |    fps              | 618      |
# |    time_elapsed     | 537      |
# |    total_timesteps  | 1610534  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00533  |
# |    n_updates        | 242809   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 1632     |
# |    fps              | 617      |
# |    time_elapsed     | 542      |
# |    total_timesteps  | 1613633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00379  |
# |    n_updates        | 243584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 1636     |
# |    fps              | 617      |
# |    time_elapsed     | 549      |
# |    total_timesteps  | 1617633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00417  |
# |    n_updates        | 244584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 1640     |
# |    fps              | 617      |
# |    time_elapsed     | 555      |
# |    total_timesteps  | 1621633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00292  |
# |    n_updates        | 245584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 1644     |
# |    fps              | 617      |
# |    time_elapsed     | 562      |
# |    total_timesteps  | 1625633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00316  |
# |    n_updates        | 246584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 1648     |
# |    fps              | 617      |
# |    time_elapsed     | 568      |
# |    total_timesteps  | 1629633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00456  |
# |    n_updates        | 247584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 1652     |
# |    fps              | 617      |
# |    time_elapsed     | 575      |
# |    total_timesteps  | 1633633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.22     |
# |    n_updates        | 248584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 1656     |
# |    fps              | 617      |
# |    time_elapsed     | 581      |
# |    total_timesteps  | 1637633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00485  |
# |    n_updates        | 249584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 1660     |
# |    fps              | 617      |
# |    time_elapsed     | 588      |
# |    total_timesteps  | 1641633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0283   |
# |    n_updates        | 250584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 1664     |
# |    fps              | 617      |
# |    time_elapsed     | 594      |
# |    total_timesteps  | 1645633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00484  |
# |    n_updates        | 251584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 1668     |
# |    fps              | 617      |
# |    time_elapsed     | 600      |
# |    total_timesteps  | 1649633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00611  |
# |    n_updates        | 252584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 1672     |
# |    fps              | 617      |
# |    time_elapsed     | 607      |
# |    total_timesteps  | 1653633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00546  |
# |    n_updates        | 253584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 1676     |
# |    fps              | 617      |
# |    time_elapsed     | 613      |
# |    total_timesteps  | 1657633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00364  |
# |    n_updates        | 254584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 1680     |
# |    fps              | 617      |
# |    time_elapsed     | 620      |
# |    total_timesteps  | 1661633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00556  |
# |    n_updates        | 255584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 1684     |
# |    fps              | 617      |
# |    time_elapsed     | 626      |
# |    total_timesteps  | 1665633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00501  |
# |    n_updates        | 256584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 1688     |
# |    fps              | 617      |
# |    time_elapsed     | 633      |
# |    total_timesteps  | 1669633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00428  |
# |    n_updates        | 257584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 1692     |
# |    fps              | 617      |
# |    time_elapsed     | 639      |
# |    total_timesteps  | 1673633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00345  |
# |    n_updates        | 258584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 1696     |
# |    fps              | 617      |
# |    time_elapsed     | 645      |
# |    total_timesteps  | 1677633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00483  |
# |    n_updates        | 259584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 1700     |
# |    fps              | 617      |
# |    time_elapsed     | 652      |
# |    total_timesteps  | 1681633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00427  |
# |    n_updates        | 260584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 1704     |
# |    fps              | 617      |
# |    time_elapsed     | 658      |
# |    total_timesteps  | 1685633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00453  |
# |    n_updates        | 261584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 1708     |
# |    fps              | 617      |
# |    time_elapsed     | 665      |
# |    total_timesteps  | 1689633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00553  |
# |    n_updates        | 262584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 1712     |
# |    fps              | 617      |
# |    time_elapsed     | 671      |
# |    total_timesteps  | 1693633  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00657  |
# |    n_updates        | 263584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.834    |
# | time/               |          |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12392    |
# |    fps              | 483      |
# |    time_elapsed     | 21148    |
# |    total_timesteps  | 11496958 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.011    |
# |    n_updates        | 2714415  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12396    |
# |    fps              | 483      |
# |    time_elapsed     | 21157    |
# |    total_timesteps  | 11500958 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00399  |
# |    n_updates        | 2715415  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12400    |
# |    fps              | 483      |
# |    time_elapsed     | 21165    |
# |    total_timesteps  | 11503978 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0074   |
# |    n_updates        | 2716170  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12404    |
# |    fps              | 483      |
# |    time_elapsed     | 21174    |
# |    total_timesteps  | 11507978 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0319   |
# |    n_updates        | 2717170  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12408    |
# |    fps              | 483      |
# |    time_elapsed     | 21183    |
# |    total_timesteps  | 11511978 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00986  |
# |    n_updates        | 2718170  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12412    |
# |    fps              | 483      |
# |    time_elapsed     | 21188    |
# |    total_timesteps  | 11513331 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0324   |
# |    n_updates        | 2718508  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12416    |
# |    fps              | 482      |
# |    time_elapsed     | 21196    |
# |    total_timesteps  | 11516482 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0154   |
# |    n_updates        | 2719296  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12420    |
# |    fps              | 482      |
# |    time_elapsed     | 21204    |
# |    total_timesteps  | 11519666 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0377   |
# |    n_updates        | 2720092  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12424    |
# |    fps              | 482      |
# |    time_elapsed     | 21213    |
# |    total_timesteps  | 11523666 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00665  |
# |    n_updates        | 2721092  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12428    |
# |    fps              | 482      |
# |    time_elapsed     | 21221    |
# |    total_timesteps  | 11527076 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00426  |
# |    n_updates        | 2721944  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12432    |
# |    fps              | 482      |
# |    time_elapsed     | 21230    |
# |    total_timesteps  | 11531076 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0169   |
# |    n_updates        | 2722944  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12436    |
# |    fps              | 482      |
# |    time_elapsed     | 21238    |
# |    total_timesteps  | 11533896 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00775  |
# |    n_updates        | 2723649  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12440    |
# |    fps              | 482      |
# |    time_elapsed     | 21245    |
# |    total_timesteps  | 11536718 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0101   |
# |    n_updates        | 2724355  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12444    |
# |    fps              | 482      |
# |    time_elapsed     | 21250    |
# |    total_timesteps  | 11537740 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0101   |
# |    n_updates        | 2724610  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12448    |
# |    fps              | 482      |
# |    time_elapsed     | 21259    |
# |    total_timesteps  | 11541740 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00577  |
# |    n_updates        | 2725610  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12452    |
# |    fps              | 482      |
# |    time_elapsed     | 21267    |
# |    total_timesteps  | 11544790 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0136   |
# |    n_updates        | 2726373  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12456    |
# |    fps              | 482      |
# |    time_elapsed     | 21276    |
# |    total_timesteps  | 11548790 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.017    |
# |    n_updates        | 2727373  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12460    |
# |    fps              | 482      |
# |    time_elapsed     | 21281    |
# |    total_timesteps  | 11550465 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0279   |
# |    n_updates        | 2727792  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12464    |
# |    fps              | 482      |
# |    time_elapsed     | 21286    |
# |    total_timesteps  | 11551537 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.011    |
# |    n_updates        | 2728060  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12468    |
# |    fps              | 482      |
# |    time_elapsed     | 21293    |
# |    total_timesteps  | 11554559 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.264    |
# |    n_updates        | 2728815  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12472    |
# |    fps              | 482      |
# |    time_elapsed     | 21302    |
# |    total_timesteps  | 11558485 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00547  |
# |    n_updates        | 2729797  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12476    |
# |    fps              | 482      |
# |    time_elapsed     | 21309    |
# |    total_timesteps  | 11560922 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00368  |
# |    n_updates        | 2730406  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12480    |
# |    fps              | 482      |
# |    time_elapsed     | 21315    |
# |    total_timesteps  | 11563227 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0113   |
# |    n_updates        | 2730982  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12484    |
# |    fps              | 482      |
# |    time_elapsed     | 21322    |
# |    total_timesteps  | 11565769 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00835  |
# |    n_updates        | 2731618  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12488    |
# |    fps              | 482      |
# |    time_elapsed     | 21330    |
# |    total_timesteps  | 11568712 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.007    |
# |    n_updates        | 2732353  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12492    |
# |    fps              | 482      |
# |    time_elapsed     | 21338    |
# |    total_timesteps  | 11572280 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.102    |
# |    n_updates        | 2733245  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12496    |
# |    fps              | 482      |
# |    time_elapsed     | 21343    |
# |    total_timesteps  | 11573396 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00417  |
# |    n_updates        | 2733524  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12500    |
# |    fps              | 482      |
# |    time_elapsed     | 21350    |
# |    total_timesteps  | 11576572 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0169   |
# |    n_updates        | 2734318  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12504    |
# |    fps              | 482      |
# |    time_elapsed     | 21358    |
# |    total_timesteps  | 11579412 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0147   |
# |    n_updates        | 2735028  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12508    |
# |    fps              | 482      |
# |    time_elapsed     | 21366    |
# |    total_timesteps  | 11582725 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0103   |
# |    n_updates        | 2735857  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12512    |
# |    fps              | 482      |
# |    time_elapsed     | 21374    |
# |    total_timesteps  | 11586368 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0233   |
# |    n_updates        | 2736767  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12516    |
# |    fps              | 482      |
# |    time_elapsed     | 21380    |
# |    total_timesteps  | 11588255 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00879  |
# |    n_updates        | 2737239  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12520    |
# |    fps              | 482      |
# |    time_elapsed     | 21387    |
# |    total_timesteps  | 11590551 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00971  |
# |    n_updates        | 2737813  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12524    |
# |    fps              | 482      |
# |    time_elapsed     | 21396    |
# |    total_timesteps  | 11594551 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00607  |
# |    n_updates        | 2738813  |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 12528    |
# |    fps              | 482      |
# |    time_elapsed     | 21406    |
# |    total_timesteps  | 11598091 |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0104   |
# |    n_updates        | 2739698  |
# ----------------------------------
# Training Interrupted
# Saving Model

# %%
# Evaluate the model
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=1)
print(f"Mean Reward: {mean_reward}, Std Reward: {std_reward}")
# Out:
# Mean Reward: 0.48489999771118164, Std Reward: 0.0

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
# save_path = "./models/dqn_intelligoal_a1_works-100"
save_path = "./models/intelligoal_a3"

# %%
def make_env():
    def _init():
        env = IntelliGoal()
        env.render_mode = 'human'
        return env
    return _init

# Wrap your environment in a DummyVecEnv for compatibility
env = DummyVecEnv([make_env()])

model = DQN.load(save_path, env=env, device=device)

def run_model():
    obs = env.reset()  # This will now be in the correct batch format
    done = False
    while True:
        action, _states = model.predict(obs, deterministic=True)
        obs, rewards, done, info = env.step(action)
        env.render()
        if done:
            print("Episode Finished with Reward - ", rewards[0])
            obs = env.reset()

try:
    run_model()
except:
    print("Environment Closed")
# Out:
# Episode Finished with Reward -  -0.6575
# Environment Closed

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
