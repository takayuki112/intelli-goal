# %%
import pygame
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import math
import random

# %%
class IntelliGoal(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(s):
        super(IntelliGoal, s).__init__()
        
        s.screen_width = 1240
        s.screen_height = 800
        s.border_width = 10
        s.screen = None
        
        s.goal_radius = 20
        s.player_radius = 10
        
        s.player_speed = 1
        
        
        # State information
        s.player_x = 0
        s.player_y = 0
        s.goal_x = 0
        s.goal_y = 0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        s.reward = 0
        
        s.done = False
        s.trucated = False
        s.truncation_step_limit = 1000
        s.truncation_step_counter = 0
        s.goal_spawn_range = 300
        
        
        # State and Action spaces
        s.action_space = spaces.Discrete(5) # 0: No movement, 1: Up, 2: Down, 3: Left, 4: Right
        # observation space = [player_x, player_y, goal_x, goal_y]
        s.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 0]), 
            high=np.array([s.screen_width, s.screen_height, s.screen_width, s.screen_height]), 
            dtype=np.int32
        )
    
    def seed(s, seed=None):
        if seed is not None and (seed < 0 or seed >= 2**32):
            raise ValueError("Seed must be between 0 and 2**32 - 1")
        s.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]
        
    def reset(s, seed=0):
        s.seed(seed)
        
        s.player_x = s.screen_width // 2
        s.player_y = s.screen_height // 2
        
        s.goal_x, s.goal_y = s.respawn_goal()
        
        s.reward = 0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        
        s.done = False
        s.trucated = False
        s.truncation_step_counter = 0
        
        return s.state, {}
    
    def respawn_goal(s):
        s.goal_x = s.player_x + random.randint(-s.goal_spawn_range, s.goal_spawn_range)
        s.goal_y = s.player_y + random.randint(-s.goal_spawn_range, s.goal_spawn_range)
        
        # clip the goal to the screen
        offset = s.border_width + s.goal_radius
        s.goal_x = min( max(s.goal_x, offset), s.screen_width - offset)
        s.goal_y = min( max(s.goal_y, offset), s.screen_height - offset)
        
        pygame.time.wait(300)
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        return s.goal_x, s.goal_y
        
    def step(s, action):
        #################
        #do more here?
        #################
        
        s.reward = 0
        s.do_action(action)
        s.calculate_step_reward()
        
        s.truncation_step_counter += 1
        if s.truncation_step_counter >= s.truncation_step_limit:
            s.reward -= 1
            s.trucated = True
            s.done = True

        if s.reward < -1:
            # s.reward = -1
            s.trucated = True
        
        # if s.reward > 1:
        #     s.reward = 1
        
        
        return s.state, s.reward, s.done, s.trucated, {}
        
   
    def do_action(s, action):
        if not s.action_space.contains(action):
            print("Invalid Action")
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        s.player_x += (action == 4)*s.player_speed - (action == 3)*s.player_speed 
        s.player_y += (action == 2)*s.player_speed - (action == 1)*s.player_speed
        
    def calculate_step_reward(s):
        # Distance between player and goal
        distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)

        # Check if the red dot touches the border
        if s.player_x not in range(s.border_width, s.screen_width - s.border_width) or s.player_y not in range(s.border_width, s.screen_height - s.border_width):
            s.player_x, s.player_y = s.screen_width // 2, s.screen_height // 2
            s.reward = -1
            s.trucated = True
            s.done = True

        # Check if the goal is reached within a certain range
        if distance < s.goal_radius + s.player_radius:
            s.goal_x, s.goal_y = s.respawn_goal()
            s.reward += 1.5
            s.done = True  
    
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        # Reward the agent for getting closer to the goal
        if s.prev_distance > distance:
            s.reward = 0.5
        if s.prev_distance < distance:
            s.reward = -0.7
        
        # Penalize the agent for taking too long
        # s.reward -= 0.00008
     
    
    def keyboard_input(s):
        keys = pygame.key.get_pressed()
        # 1: Up, 2: Down, 3: Left, 4: Right
        if keys[pygame.K_UP]:
            return 1
        if keys[pygame.K_DOWN]:
            return 2
        if keys[pygame.K_LEFT]:
            return 3
        if keys[pygame.K_RIGHT]:
            return 4
        return 0
        
    
    def render(s, mode = 'human'):
        if s.screen == None:
            pygame.init()
            s.screen = pygame.display.set_mode((s.screen_width, s.screen_height))
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
        s.player_x, s.player_y, s.goal_x, s.goal_y = s.state
        
        s.screen.fill((0, 0, 0))
        RED = (255, 0, 0)
        BLUE = (0, 0, 255)
        BORDER_COLOR = (255, 255, 0)
        
        # Draw the border
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.border_width, s.screen_height))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, s.screen_height - s.border_width, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (s.screen_width - s.border_width, 0, s.border_width, s.screen_height))

        # Draw the red dot
        pygame.draw.circle(s.screen, RED, (s.player_x, s.player_y), 10)

        # Draw the blue dot
        pygame.draw.circle(s.screen, BLUE, (s.goal_x, s.goal_y), s.goal_radius)
        
        #Display Reward on pygame screen
        font = pygame.font.Font(None, 36)
        text = font.render("Reward: " + str(round(s.reward, 5)), True, (255, 255, 255))
        s.screen.blit(text, (10, 10))
        
        pygame.display.update()
    
    def close(s):
        pygame.quit()

# %%
# Test Env with keyboard input actions
test_env = IntelliGoal()
test_env.reset(0)
done = False
i = 1

# while True:
#     try:
#         test_env.render()
#         action = test_env.keyboard_input()
#         state, reward, done, truncated, _i = test_env.step(action)
#         if done or truncated:
#             print("Reward at step - ", i, " : ", round(reward, 5))
#             i += 1
#             test_env.reset(0)
#     except:
#         print("Environment Closed")
#         break

# while True:
#     test_env.render()
#     action = test_env.keyboard_input()
#     state, reward, done, truncated, _i = test_env.step(action)
#     if done or truncated:
#         print("Reward at step - ", i, " : ", round(reward, 5))
#         i += 1
#         test_env.reset(0)

# %% [markdown]
# # DQN Learning Algorithm

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
import torch
device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
    print("Using GPU - ", torch.cuda.get_device_name(0))
# Out:
# Using GPU -  NVIDIA RTX A500 Laptop GPU

# %%
env = IntelliGoal()
check_env(env)

# %%
def make_env():
    env = IntelliGoal()
    return env

num_envs = 4
take_logs = False
device = "cuda"

if take_logs:
    log_dir = "./logs/ppo_intelligoal_a3_explore-more"
else:
    log_dir = None
      
if num_envs == 1:
    env = DummyVecEnv([make_env] * num_envs)
else:
    env = SubprocVecEnv([make_env] * num_envs)


# model = PPO("MlpPolicy", env, verbose=1, device=device)

# Define DQN model with specific parameters
model = DQN("MlpPolicy", env, verbose=1, 
            buffer_size=10000, 
            learning_rate=0.001, 
            batch_size=64, 
            tau=1.0, 
            gamma=0.99, 
            train_freq=4, 
            gradient_steps=1, 
            exploration_fraction=0.5,
            exploration_initial_eps=0.9, 
            exploration_final_eps=0.01, 
            target_update_interval=500, 
            max_grad_norm=10, 
            tensorboard_log="./logs/dqn_intelligoal_tensorboard/", 
            device=device)
# Out:
# Using cuda device

# %%
# Start New training session
save_path = "./models/dqn_step_rewards_a1"

# if os.path.exists(save_path +".zip"):
#     #append number to the file name
#     i = save_path[-1]
#     i = int(i) + 1
#     save_path = save_path[:-1] + str(i)
#     print("Model already exists. Saving new one as - ", save_path)
    
try:
    model.learn(total_timesteps=9999999999)
    model.save(save_path)
except KeyboardInterrupt:
    print("Training Interrupted")
    model.save(save_path)
# Out:
# Logging to ./logs/dqn_intelligoal_tensorboard/DQN_10
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1403     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.594    |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1720     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.117    |
# |    n_updates        | 493      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1867     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.25     |
# |    n_updates        | 743      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1956     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.529    |
# |    n_updates        | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2005     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.322    |
# |    n_updates        | 1243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2023     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.3      |
# |    n_updates        | 1493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2033     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 28000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.374    |
# |    n_updates        | 1743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2042     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 32000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.71     |
# |    n_updates        | 1993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2058     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.342    |
# |    n_updates        | 2243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2074     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 40000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.167    |
# |    n_updates        | 2493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2090     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 44000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.156    |
# |    n_updates        | 2743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2016     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 48000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.216    |
# |    n_updates        | 2993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1991     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 52000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.151    |
# |    n_updates        | 3243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1960     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 56000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.426    |
# |    n_updates        | 3493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1956     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.243    |
# |    n_updates        | 3743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1915     |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 64000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.69     |
# |    n_updates        | 3993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1898     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 68000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.448    |
# |    n_updates        | 4243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1883     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 72000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.93     |
# |    n_updates        | 4493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1863     |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 76000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.222    |
# |    n_updates        | 4743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1846     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 80000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0468   |
# |    n_updates        | 4993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1832     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 84000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.168    |
# |    n_updates        | 5243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1827     |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 88000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.277    |
# |    n_updates        | 5493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1800     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 92000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.249    |
# |    n_updates        | 5743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1748     |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 96000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.118    |
# |    n_updates        | 5993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1712     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 100000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.272    |
# |    n_updates        | 6243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1672     |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 104000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.131    |
# |    n_updates        | 6493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1647     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 108000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.296    |
# |    n_updates        | 6743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1633     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 112000   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.132    |
# |    n_updates        | 6993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1606     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 114876   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.986    |
# |    n_updates        | 7173     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1587     |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 118876   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.304    |
# |    n_updates        | 7423     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1582     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 122876   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.158    |
# |    n_updates        | 7673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1565     |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 125888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.115    |
# |    n_updates        | 7861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1561     |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 129888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0967   |
# |    n_updates        | 8111     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1556     |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 133888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.198    |
# |    n_updates        | 8361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1551     |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 137888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.21     |
# |    n_updates        | 8611     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1544     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 141888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.117    |
# |    n_updates        | 8861     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1538     |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 145888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0706   |
# |    n_updates        | 9111     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1537     |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 149888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.113    |
# |    n_updates        | 9361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1534     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 153888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.234    |
# |    n_updates        | 9611     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1519     |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 156004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0676   |
# |    n_updates        | 9744     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1516     |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 160004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.126    |
# |    n_updates        | 9994     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1513     |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 164004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.164    |
# |    n_updates        | 10244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1507     |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 168004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0619   |
# |    n_updates        | 10494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1503     |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 172004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.179    |
# |    n_updates        | 10744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1502     |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 176004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0965   |
# |    n_updates        | 10994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1501     |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 180004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0321   |
# |    n_updates        | 11244    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1498     |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 184004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0478   |
# |    n_updates        | 11494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1495     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 188004   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0585   |
# |    n_updates        | 11744    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1487     |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 191556   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.09     |
# |    n_updates        | 11966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1482     |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 195556   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0639   |
# |    n_updates        | 12216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1480     |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 199556   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.39     |
# |    n_updates        | 12466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1481     |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 203556   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0508   |
# |    n_updates        | 12716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1481     |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 207556   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.26     |
# |    n_updates        | 12966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1478     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 211556   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.63     |
# |    n_updates        | 13216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1476     |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 215556   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.1      |
# |    n_updates        | 13466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1473     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 219556   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.107    |
# |    n_updates        | 13716    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1466     |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 222960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0393   |
# |    n_updates        | 13928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1466     |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 226960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0624   |
# |    n_updates        | 14178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1461     |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 230960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0864   |
# |    n_updates        | 14428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1458     |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 234960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.114    |
# |    n_updates        | 14678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1455     |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 238960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0432   |
# |    n_updates        | 14928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1453     |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 242960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.121    |
# |    n_updates        | 15178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1453     |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 246960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0613   |
# |    n_updates        | 15428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1452     |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 250960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0804   |
# |    n_updates        | 15678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1452     |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 254960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0333   |
# |    n_updates        | 15928    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1451     |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 258960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0941   |
# |    n_updates        | 16178    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1449     |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 262960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.116    |
# |    n_updates        | 16428    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1447     |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 266960   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.169    |
# |    n_updates        | 16678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1442     |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 269968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0549   |
# |    n_updates        | 16866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1441     |
# |    time_elapsed     | 189      |
# |    total_timesteps  | 273968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.117    |
# |    n_updates        | 17116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1441     |
# |    time_elapsed     | 192      |
# |    total_timesteps  | 277968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.148    |
# |    n_updates        | 17366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1441     |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 281968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.06     |
# |    n_updates        | 17616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1440     |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 285968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.166    |
# |    n_updates        | 17866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1438     |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 289968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0444   |
# |    n_updates        | 18116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1438     |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 293968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0149   |
# |    n_updates        | 18366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1438     |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 297968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0484   |
# |    n_updates        | 18616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1438     |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 301968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0157   |
# |    n_updates        | 18866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1437     |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 305968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0156   |
# |    n_updates        | 19116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1436     |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 309968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0701   |
# |    n_updates        | 19366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1435     |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 313968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0252   |
# |    n_updates        | 19616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1433     |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 317968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0199   |
# |    n_updates        | 19866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1433     |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 321968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.108    |
# |    n_updates        | 20116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1433     |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 325968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0281   |
# |    n_updates        | 20366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1432     |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 329968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0241   |
# |    n_updates        | 20616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1430     |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 333968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.103    |
# |    n_updates        | 20866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1428     |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 337968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0208   |
# |    n_updates        | 21116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1426     |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 341888   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0326   |
# |    n_updates        | 21361    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1425     |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 345664   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0291   |
# |    n_updates        | 21597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1424     |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 349664   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0436   |
# |    n_updates        | 21847    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1425     |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 353664   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0519   |
# |    n_updates        | 22097    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1425     |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 357664   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0192   |
# |    n_updates        | 22347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1424     |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 361664   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0308   |
# |    n_updates        | 22597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1420     |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 364792   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0294   |
# |    n_updates        | 22793    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1416     |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 367056   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0309   |
# |    n_updates        | 22934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1416     |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 371056   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0282   |
# |    n_updates        | 23184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1416     |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 375056   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.012    |
# |    n_updates        | 23434    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1414     |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 378964   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0555   |
# |    n_updates        | 23679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1410     |
# |    time_elapsed     | 270      |
# |    total_timesteps  | 382012   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0287   |
# |    n_updates        | 23869    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1406     |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 385968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.892    |
# |    n_updates        | 24116    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1404     |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 389968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0438   |
# |    n_updates        | 24366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1405     |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 393968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0318   |
# |    n_updates        | 24616    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1406     |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 397968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.112    |
# |    n_updates        | 24866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1403     |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 401052   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0186   |
# |    n_updates        | 25059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1403     |
# |    time_elapsed     | 288      |
# |    total_timesteps  | 405052   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0351   |
# |    n_updates        | 25309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1402     |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 409052   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.199    |
# |    n_updates        | 25559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3636     |
# |    fps              | 1276     |
# |    time_elapsed     | 2721     |
# |    total_timesteps  | 3472584  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0212   |
# |    n_updates        | 217030   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3640     |
# |    fps              | 1276     |
# |    time_elapsed     | 2724     |
# |    total_timesteps  | 3476584  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00606  |
# |    n_updates        | 217280   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3644     |
# |    fps              | 1276     |
# |    time_elapsed     | 2726     |
# |    total_timesteps  | 3480584  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0156   |
# |    n_updates        | 217530   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3648     |
# |    fps              | 1276     |
# |    time_elapsed     | 2729     |
# |    total_timesteps  | 3483864  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00386  |
# |    n_updates        | 217735   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3652     |
# |    fps              | 1276     |
# |    time_elapsed     | 2732     |
# |    total_timesteps  | 3487864  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00612  |
# |    n_updates        | 217985   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3656     |
# |    fps              | 1276     |
# |    time_elapsed     | 2735     |
# |    total_timesteps  | 3491864  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00376  |
# |    n_updates        | 218235   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3660     |
# |    fps              | 1275     |
# |    time_elapsed     | 2739     |
# |    total_timesteps  | 3494856  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00871  |
# |    n_updates        | 218422   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3664     |
# |    fps              | 1275     |
# |    time_elapsed     | 2742     |
# |    total_timesteps  | 3498856  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00476  |
# |    n_updates        | 218672   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3668     |
# |    fps              | 1276     |
# |    time_elapsed     | 2745     |
# |    total_timesteps  | 3502856  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.019    |
# |    n_updates        | 218922   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3672     |
# |    fps              | 1276     |
# |    time_elapsed     | 2748     |
# |    total_timesteps  | 3506856  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0209   |
# |    n_updates        | 219172   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3676     |
# |    fps              | 1276     |
# |    time_elapsed     | 2751     |
# |    total_timesteps  | 3510856  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00819  |
# |    n_updates        | 219422   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3680     |
# |    fps              | 1276     |
# |    time_elapsed     | 2754     |
# |    total_timesteps  | 3514856  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.885    |
# |    n_updates        | 219672   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3684     |
# |    fps              | 1275     |
# |    time_elapsed     | 2757     |
# |    total_timesteps  | 3518684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00563  |
# |    n_updates        | 219911   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3688     |
# |    fps              | 1276     |
# |    time_elapsed     | 2760     |
# |    total_timesteps  | 3522684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00595  |
# |    n_updates        | 220161   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3692     |
# |    fps              | 1276     |
# |    time_elapsed     | 2763     |
# |    total_timesteps  | 3526684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00974  |
# |    n_updates        | 220411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3696     |
# |    fps              | 1276     |
# |    time_elapsed     | 2765     |
# |    total_timesteps  | 3530684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0163   |
# |    n_updates        | 220661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3700     |
# |    fps              | 1276     |
# |    time_elapsed     | 2768     |
# |    total_timesteps  | 3534684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00626  |
# |    n_updates        | 220911   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3704     |
# |    fps              | 1276     |
# |    time_elapsed     | 2771     |
# |    total_timesteps  | 3538684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0085   |
# |    n_updates        | 221161   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3708     |
# |    fps              | 1276     |
# |    time_elapsed     | 2774     |
# |    total_timesteps  | 3542684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0181   |
# |    n_updates        | 221411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3712     |
# |    fps              | 1276     |
# |    time_elapsed     | 2777     |
# |    total_timesteps  | 3546684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00424  |
# |    n_updates        | 221661   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3716     |
# |    fps              | 1276     |
# |    time_elapsed     | 2780     |
# |    total_timesteps  | 3550684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0295   |
# |    n_updates        | 221911   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3720     |
# |    fps              | 1277     |
# |    time_elapsed     | 2783     |
# |    total_timesteps  | 3554684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0126   |
# |    n_updates        | 222161   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3724     |
# |    fps              | 1277     |
# |    time_elapsed     | 2785     |
# |    total_timesteps  | 3558684  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00993  |
# |    n_updates        | 222411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3728     |
# |    fps              | 1277     |
# |    time_elapsed     | 2788     |
# |    total_timesteps  | 3561552  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.02     |
# |    n_updates        | 222590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3732     |
# |    fps              | 1277     |
# |    time_elapsed     | 2791     |
# |    total_timesteps  | 3565552  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0123   |
# |    n_updates        | 222840   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3736     |
# |    fps              | 1276     |
# |    time_elapsed     | 2794     |
# |    total_timesteps  | 3568584  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.935    |
# |    n_updates        | 223030   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3740     |
# |    fps              | 1277     |
# |    time_elapsed     | 2797     |
# |    total_timesteps  | 3572584  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00281  |
# |    n_updates        | 223280   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3744     |
# |    fps              | 1276     |
# |    time_elapsed     | 2800     |
# |    total_timesteps  | 3575640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0153   |
# |    n_updates        | 223471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3748     |
# |    fps              | 1277     |
# |    time_elapsed     | 2802     |
# |    total_timesteps  | 3579640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0113   |
# |    n_updates        | 223721   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3752     |
# |    fps              | 1277     |
# |    time_elapsed     | 2805     |
# |    total_timesteps  | 3583640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00602  |
# |    n_updates        | 223971   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3756     |
# |    fps              | 1277     |
# |    time_elapsed     | 2808     |
# |    total_timesteps  | 3587640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0101   |
# |    n_updates        | 224221   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3760     |
# |    fps              | 1277     |
# |    time_elapsed     | 2811     |
# |    total_timesteps  | 3591640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00526  |
# |    n_updates        | 224471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3764     |
# |    fps              | 1277     |
# |    time_elapsed     | 2814     |
# |    total_timesteps  | 3595640  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0155   |
# |    n_updates        | 224721   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3768     |
# |    fps              | 1277     |
# |    time_elapsed     | 2817     |
# |    total_timesteps  | 3599304  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0309   |
# |    n_updates        | 224950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 3772     |
# |    fps              | 1277     |
# |    time_elapsed     | 2820     |
# |    total_timesteps  | 3603304  |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00237  |
# |    n_updates        | 225200   |
# ----------------------------------
# Training Interrupted

# %%
def make_env():
    env = IntelliGoal()
    return env

num_envs = 2
take_logs = False
device = "cuda"

if take_logs:
    log_dir = "./logs/ppo_intelligoal_a3_explore-more"
else:
    log_dir = None
      
if num_envs == 1:
    env = DummyVecEnv([make_env] * num_envs)
else:
    env = SubprocVecEnv([make_env] * num_envs)

# %%
def make_env():
    env = IntelliGoal()
    return env

num_envs = 4
take_logs = False
device = "cuda"

if take_logs:
    log_dir = "./logs/ppo_intelligoal_a3_explore-more"
else:
    log_dir = None
      
if num_envs == 1:
    env = DummyVecEnv([make_env] * num_envs)
else:
    env = SubprocVecEnv([make_env] * num_envs)


model = DQN("MlpPolicy", env, verbose=1, 
            buffer_size=10000,  
            batch_size=64, 
            learning_rate=0.005,
            tau=1.0, 
            gamma=0.99, 
            train_freq=4, 
            gradient_steps=1, 
            exploration_fraction=0.5,
            exploration_initial_eps=0.9, 
            exploration_final_eps=0.01, 
            target_update_interval=500, 
            max_grad_norm=10, 
            tensorboard_log="./logs/dqn_intelligoal_tensorboard/", 
            device=device)
# Out:
# Using cuda device

# %%
save_path = "./models/dqn_step_rewards_a1"

# %%
# Load and resume training from saved model
try:
    model.load(path = save_path, env = env)
    model.learn(total_timesteps=100000000, reset_num_timesteps=False, progress_bar=False)
    model.save(save_path)
except KeyboardInterrupt:
    print("Training Interrupted")
    print("Saving Model")
    model.save(save_path)
    print("Model Saved")
# Out:
# Logging to ./logs/dqn_intelligoal_tensorboard/DQN_10
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1014     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 4000     |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 1.49     |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1112     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 1.56     |
# |    n_updates        | 493      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1111     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 1.38     |
# |    n_updates        | 743      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1111     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 0.66     |
# |    n_updates        | 993      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1114     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 1.67     |
# |    n_updates        | 1243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1125     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 1.02     |
# |    n_updates        | 1493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1130     |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 28000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 0.697    |
# |    n_updates        | 1743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1130     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 32000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 2.04     |
# |    n_updates        | 1993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1134     |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 1.56     |
# |    n_updates        | 2243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1140     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 40000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 0.396    |
# |    n_updates        | 2493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1116     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 44000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 1.07     |
# |    n_updates        | 2743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1111     |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 48000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 0.408    |
# |    n_updates        | 2993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1106     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 52000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 1.28     |
# |    n_updates        | 3243     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1096     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 56000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 0.466    |
# |    n_updates        | 3493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1087     |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 0.607    |
# |    n_updates        | 3743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1076     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 64000    |
# | train/              |          |
# |    learning_rate    | 0.005    |
# |    loss             | 0.244    |
# |    n_updates        | 3993     |
# ----------------------------------

# %%
# Evaluate the model
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=1)
print(f"Mean Reward: {mean_reward}, Std Reward: {std_reward}")
# Out:
# Mean Reward: 0.48489999771118164, Std Reward: 0.0

# %%
# from stable_baselines3.common.vec_env import DummyVecEnv
# save_path = "./models/dqn_intelligoal_a1_works-100"
# save_path = "./models/intelligoal_a3"
save_path = "./models/dqn_step_rewards_a1-more-progress-seen"
device = 'cuda'

# %%
def make_env():
    def _init():
        env = IntelliGoal()
        env.render_mode = 'human'
        return env
    return _init

# Wrap your environment in a DummyVecEnv for compatibility
env = DummyVecEnv([make_env()])

model = DQN.load(save_path, env=env, device=device)

def run_model():
    obs = env.reset()  # This will now be in the correct batch format
    done = False
    while True:
        action, _states = model.predict(obs, deterministic=True)
        obs, rewards, done, info = env.step(action)
        env.render()
        if done:
            print("Episode Finished with Reward - ", rewards[0])
            obs = env.reset()

try:
    run_model()
except:
    print("Environment Closed")
# Out:
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  -1.7
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Environment Closed
