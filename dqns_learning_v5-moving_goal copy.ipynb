# %%
import pygame
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import math
import random
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class IntelliGoal(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(s):
        super(IntelliGoal, s).__init__()
        
        s.screen_width = 1240
        s.screen_height = 800
        s.border_width = 10
        s.screen = None
        
        s.goal_radius = 20
        s.player_radius = 10
        
        s.player_speed = 1
        
        
        # State information
        s.player_x = 0
        s.player_y = 0
        s.goal_x = 0.0
        s.goal_y = 0.0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        s.reward = 0
        
        s.done = False
        s.trucated = False
        s.truncation_step_limit = 1000
        s.truncation_step_counter = 0
        s.goal_spawn_range = 300
        
        s.prev_goal_position = (0, 0)  # Previous position of the goal
        s.position_change_timer = 0  # Timer to track position changes of the goal

        s.goal_speed = 0.1
        s.goal_direction = (0, 0)  # Initial direction of the goal
        s.direction_change_timer = 0
        s.direction_change_interval = 90  # Interval for changing direction (in frames)
        s.constant_goal_speed_increment = 0.000
        s.level_up_goal_speed_increment = 0.0
        
        
        # State and Action spaces
        s.action_space = spaces.Discrete(5) # 0: No movement, 1: Up, 2: Down, 3: Left, 4: Right
        # observation space = [player_x, player_y, goal_x, goal_y]
        s.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 0]), 
            high=np.array([s.screen_width, s.screen_height, s.screen_width, s.screen_height]), 
            dtype=np.int32
        )
    
    def seed(s, seed=None):
        if seed is not None and (seed < 0 or seed >= 2**32):
            raise ValueError("Seed must be between 0 and 2**32 - 1")
        s.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]
        
    def reset(s, seed=0):
        s.seed(seed)
        
        s.player_x = s.screen_width // 2
        s.player_y = s.screen_height // 2
        
        s.goal_x, s.goal_y = s.respawn_goal()
        
        s.reward = 0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        
        s.done = False
        s.trucated = False
        s.truncation_step_counter = 0
        
        return s.state, {}
    
    def respawn_goal(s):
        s.goal_x = s.player_x + random.randint(-s.goal_spawn_range, s.goal_spawn_range)
        s.goal_y = s.player_y + random.randint(-s.goal_spawn_range, s.goal_spawn_range)
        
        # clip the goal to the screen
        offset = s.border_width + s.goal_radius
        s.goal_x = min( max(s.goal_x, offset), s.screen_width - offset)
        s.goal_y = min( max(s.goal_y, offset), s.screen_height - offset)
        
        pygame.time.wait(300)
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        return s.goal_x, s.goal_y
        
    def step(s, action):
        #################
        #do more here?
        #################
        
        s.reward = 0
        s.do_action(action)
        s.calculate_step_reward()

        s.dynamic_goal()
        
        s.truncation_step_counter += 1
        if s.truncation_step_counter >= s.truncation_step_limit:
            s.reward -= 1
            s.trucated = True
            s.done = True

        if s.reward < -1:
            # s.reward = -1
            s.trucated = True
        
        # if s.reward > 1:
        #     s.reward = 1
        
        
        return s.state, s.reward, s.done, s.trucated, {}
        
   
    def do_action(s, action):
        if not s.action_space.contains(action):
            print("Invalid Action")
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        s.player_x += (action == 4)*s.player_speed - (action == 3)*s.player_speed 
        s.player_y += (action == 2)*s.player_speed - (action == 1)*s.player_speed
        
    def calculate_step_reward(s):
        # Distance between player and goal
        distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)

        # Check if the red dot touches the border
        if s.player_x not in range(s.border_width, s.screen_width - s.border_width) or s.player_y not in range(s.border_width, s.screen_height - s.border_width):
            s.player_x, s.player_y = s.screen_width // 2, s.screen_height // 2
            s.reward = -1
            s.trucated = True
            s.done = True

        # Check if the goal is reached within a certain range
        if distance < s.goal_radius + s.player_radius:
            s.goal_x, s.goal_y = s.respawn_goal()
            s.reward += 1.5
            s.done = True  
    
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        # Reward the agent for getting closer to the goal
        if s.prev_distance > distance:
            s.reward = 0.5
        if s.prev_distance < distance:
            s.reward = -0.7
        
        # Penalize the agent for taking too long
        # s.reward -= 0.00008
     
    def dynamic_goal(s):
            # Update goal position and direction
            if s.direction_change_timer <= 0:
                # Change direction
                s.goal_direction = (random.randint(-2, 2), random.randint(-2, 2))
                # Reset direction change timer
                s.direction_change_timer = s.direction_change_interval
            else:
                # Continue in the current direction
                s.goal_x += s.goal_direction[0] * s.goal_speed
                s.goal_y += s.goal_direction[1] * s.goal_speed
                s.direction_change_timer -= 1

            # Ensure the goal stays within the screen bounds with a margin inside the borders
            goal_margin = 25  # Adjust this value as needed
            s.goal_x = max(s.border_width + goal_margin, min(s.goal_x, s.screen_width - s.border_width - goal_margin))
            s.goal_y = max(s.border_width + goal_margin, min(s.goal_y, s.screen_height - s.border_width - goal_margin))

            # Increase goal speed gradually
            s.goal_speed += s.constant_goal_speed_increment

            # Check if the goal position is changing
            current_goal_position = (s.goal_x, s.goal_y)
            if current_goal_position == s.prev_goal_position:
                # Increment the timer if the position remains the same
                s.position_change_timer += 1
            else:
                # Reset the timer if the position changes
                s.position_change_timer = 0
                # Update the previous position
                s.prev_goal_position = current_goal_position

            # Check if the goal is stuck and change direction if necessary
            if s.position_change_timer >= 3:  #threshold as needed
                s.goal_direction = (random.randint(-2, 2), random.randint(-2, 2))
                s.position_change_timer = 0
            
            # Update the state
            s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
            
    def keyboard_input(s):
        keys = pygame.key.get_pressed()
        # 1: Up, 2: Down, 3: Left, 4: Right
        if keys[pygame.K_UP]:
            return 1
        if keys[pygame.K_DOWN]:
            return 2
        if keys[pygame.K_LEFT]:
            return 3
        if keys[pygame.K_RIGHT]:
            return 4
        return 0
        
    
    def render(s, mode = 'human'):
        if s.screen == None:
            pygame.init()
            s.screen = pygame.display.set_mode((s.screen_width, s.screen_height))
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
        s.player_x, s.player_y, s.goal_x, s.goal_y = s.state
        
        s.screen.fill((0, 0, 0))
        RED = (255, 0, 0)
        BLUE = (0, 0, 255)
        BORDER_COLOR = (255, 255, 0)
        
        # Draw the border
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.border_width, s.screen_height))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, s.screen_height - s.border_width, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (s.screen_width - s.border_width, 0, s.border_width, s.screen_height))

        # Draw the red dot
        pygame.draw.circle(s.screen, RED, (s.player_x, s.player_y), 10)

        # Draw the blue dot
        pygame.draw.circle(s.screen, BLUE, (s.goal_x, s.goal_y), s.goal_radius)
        
        #Display Reward on pygame screen
        font = pygame.font.Font(None, 36)
        text = font.render("Reward: " + str(round(s.reward, 5)), True, (255, 255, 255))
        s.screen.blit(text, (10, 10))
        
        pygame.display.update()
    
    def close(s):
        pygame.quit()

# %%
# Test Env with keyboard input actions
test_env = IntelliGoal()
test_env.reset(0)
done = False
i = 1

while True:
    try:
        test_env.render()
        action = test_env.keyboard_input()
        state, reward, done, truncated, _i = test_env.step(action)
        if done or truncated:
            print("Reward at step - ", i, " : ", round(reward, 5))
            i += 1
            test_env.reset(0)
    except:
        print("Environment Closed")
        break

# while True:
#     test_env.render()
#     action = test_env.keyboard_input()
#     state, reward, done, truncated, _i = test_env.step(action)
#     if done or truncated:
#         print("Reward at step - ", i, " : ", round(reward, 5))
#         i += 1
#         test_env.reset(0)
# Out:
# Reward at step -  1  :  -0.5
# Reward at step -  2  :  0.5
# Reward at step -  3  :  0.5
# Reward at step -  4  :  -1
# Reward at step -  5  :  0.5
# Reward at step -  6  :  0.5
# Reward at step -  7  :  0.5
# Reward at step -  8  :  -1.7
# Reward at step -  9  :  -0.5
# Reward at step -  10  :  0.5
# Reward at step -  11  :  -1
# Reward at step -  12  :  0.5
# Reward at step -  13  :  0.5
# Reward at step -  14  :  -1
# Reward at step -  15  :  0.5
# Reward at step -  16  :  0.5
# Reward at step -  17  :  0.5
# Reward at step -  18  :  -0.5
# Reward at step -  19  :  0.5
# Reward at step -  20  :  -1
# Environment Closed

# %% [markdown]
# # DQN Learning Algorithm

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
import torch
device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
    print("Using GPU - ", torch.cuda.get_device_name(0))
# Out:
# Using GPU -  NVIDIA GeForce RTX 3050 Laptop GPU

# %%
env = IntelliGoal()
check_env(env)

# %%
def make_env():
    env = IntelliGoal()
    return env

num_envs = 12
take_logs = False
device = "cuda"

if take_logs:
    log_dir = "./logs/ppo_intelligoal_a3_explore-more"
else:
    log_dir = None
      
if num_envs == 1:
    env = DummyVecEnv([make_env] * num_envs)
else:
    env = SubprocVecEnv([make_env] * num_envs)


# model = PPO("MlpPolicy", env, verbose=1, device=device)

# Define DQN model with specific parameters
model = DQN("MlpPolicy", env, verbose=1, 
            buffer_size=10000, 
            learning_rate=0.0001, 
            batch_size=128, 
            tau=1.0, 
            gamma=0.99, 
            train_freq=4, 
            gradient_steps=1, 
            exploration_fraction=0.5,
            exploration_initial_eps=1.0, 
            exploration_final_eps=0.01, 
            target_update_interval=500, 
            max_grad_norm=10, 
            device=device)
# Out:
# Using cuda device

# %%
# Start New training session
save_path = "./models/dqn_step-rewards_a3"

# if os.path.exists(save_path +".zip"):
#     #append number to the file name
#     i = save_path[-1]
#     i = int(i) + 1
#     save_path = save_path[:-1] + str(i)
#     print("Model already exists. Saving new one as - ", save_path)
    
total_timesteps = 100000000
checkpoint_interval = 500000  # Save model every 1000 timesteps

try:
    for t in range(0, total_timesteps, checkpoint_interval):
        model.learn(total_timesteps=checkpoint_interval)
        model.save(save_path)
        print("Checkpoint saved at timestep - ", t)
except KeyboardInterrupt:
    print("Training Interrupted")
finally:
    model.save(save_path)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 2613     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.295    |
# |    n_updates        | 247      |
# ----------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 8     |
# |    fps             | 2613  |
# |    time_elapsed    | 4     |
# |    total_timesteps | 12000 |
# ------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 12    |
# |    fps             | 2612  |
# |    time_elapsed    | 4     |
# |    total_timesteps | 12000 |
# ------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 3631     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 497      |
# ----------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 20    |
# |    fps             | 3631  |
# |    time_elapsed    | 6     |
# |    total_timesteps | 24000 |
# ------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 24    |
# |    fps             | 3631  |
# |    time_elapsed    | 6     |
# |    total_timesteps | 24000 |
# ------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4139     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.144    |
# |    n_updates        | 747      |
# ----------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 32    |
# |    fps             | 4139  |
# |    time_elapsed    | 8     |
# |    total_timesteps | 36000 |
# ------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 36    |
# |    fps             | 4139  |
# |    time_elapsed    | 8     |
# |    total_timesteps | 36000 |
# ------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4432     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 48000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0468   |
# |    n_updates        | 997      |
# ----------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 44    |
# |    fps             | 4431  |
# |    time_elapsed    | 10    |
# |    total_timesteps | 48000 |
# ------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 48    |
# |    fps             | 4431  |
# |    time_elapsed    | 10    |
# |    total_timesteps | 48000 |
# ------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4600     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0961   |
# |    n_updates        | 1247     |
# ----------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 56    |
# |    fps             | 4600  |
# |    time_elapsed    | 13    |
# |    total_timesteps | 60000 |
# ------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 60    |
# |    fps             | 4600  |
# |    time_elapsed    | 13    |
# |    total_timesteps | 60000 |
# ------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4245     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 72000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0921   |
# |    n_updates        | 1497     |
# ----------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 68    |
# |    fps             | 4245  |
# |    time_elapsed    | 16    |
# |    total_timesteps | 72000 |
# ------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 72    |
# |    fps             | 4245  |
# |    time_elapsed    | 16    |
# |    total_timesteps | 72000 |
# ------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.687    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4036     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 78996    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0948   |
# |    n_updates        | 1643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.667    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4058     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 84000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0643   |
# |    n_updates        | 1747     |
# ----------------------------------
# ------------------------------
# | time/              |       |
# |    episodes        | 84    |
# |    fps             | 4058  |
# |    time_elapsed    | 20    |
# |    total_timesteps | 84000 |
# ------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 3870     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 88020    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.614    |
# |    n_updates        | 1831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 3580     |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 92520    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0815   |
# |    n_updates        | 1925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 3328     |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 95712    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0972   |
# |    n_updates        | 1991     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 3190     |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 97416    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.101    |
# |    n_updates        | 2027     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.604    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 3054     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 100020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.154    |
# |    n_updates        | 2081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.593    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 2935     |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 102660   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.636    |
# |    n_updates        | 2136     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 2871     |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 108000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0835   |
# |    n_updates        | 2247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.567    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 2780     |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 109416   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.08     |
# |    n_updates        | 2277     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 2680     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 112476   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.63     |
# |    n_updates        | 2341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 2607     |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 116460   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 2424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 2507     |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 117684   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 2449     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 2483     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 122532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.628    |
# |    n_updates        | 2550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 2418     |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 124356   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.882    |
# |    n_updates        | 2588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.494    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 2366     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 127692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0921   |
# |    n_updates        | 2658     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.488    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 2308     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 129312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0789   |
# |    n_updates        | 2691     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.466    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 2285     |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 134772   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0631   |
# |    n_updates        | 2805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 2230     |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 137040   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.1      |
# |    n_updates        | 2852     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 2171     |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 138552   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 2884     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 2145     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 140916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0944   |
# |    n_updates        | 2933     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.426    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 2107     |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 144852   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0894   |
# |    n_updates        | 3015     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.418    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 2064     |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 146988   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0973   |
# |    n_updates        | 3060     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.407    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 2037     |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 149688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.564    |
# |    n_updates        | 3116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.404    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1993     |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 150384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.136    |
# |    n_updates        | 3130     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1983     |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 152832   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 3181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.387    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1938     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 154716   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 3221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.375    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1908     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 157908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0846   |
# |    n_updates        | 3287     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.362    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1886     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 161040   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.124    |
# |    n_updates        | 3352     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.358    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1862     |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 162180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.59     |
# |    n_updates        | 3376     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.348    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1844     |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 164760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0836   |
# |    n_updates        | 3430     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.338    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1820     |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 167208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0923   |
# |    n_updates        | 3481     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.331    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1785     |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 168888   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 3516     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.323    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1761     |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 170940   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 3559     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.317    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1729     |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 172572   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.102    |
# |    n_updates        | 3593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.302    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1724     |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 176256   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.071    |
# |    n_updates        | 3669     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.297    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1693     |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 177540   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0797   |
# |    n_updates        | 3696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.285    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1674     |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 180492   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.1      |
# |    n_updates        | 3758     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.277    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1651     |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 182580   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0747   |
# |    n_updates        | 3801     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1626     |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 184224   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.074    |
# |    n_updates        | 3835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.264    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1606     |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 185856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0681   |
# |    n_updates        | 3869     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.254    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1594     |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 188484   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.105    |
# |    n_updates        | 3924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.247    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1576     |
# |    time_elapsed     | 120      |
# |    total_timesteps  | 190224   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0958   |
# |    n_updates        | 3960     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.242    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1559     |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 191352   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.104    |
# |    n_updates        | 3984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.234    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1542     |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 193548   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0596   |
# |    n_updates        | 4030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.224    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1530     |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 196032   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0595   |
# |    n_updates        | 4081     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1522     |
# |    time_elapsed     | 130      |
# |    total_timesteps  | 198948   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0477   |
# |    n_updates        | 4142     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.21     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1498     |
# |    time_elapsed     | 133      |
# |    total_timesteps  | 199620   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0645   |
# |    n_updates        | 4156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.203    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1480     |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 201324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0509   |
# |    n_updates        | 4192     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1472     |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 204684   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0549   |
# |    n_updates        | 4262     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.188    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1453     |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 205176   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0946   |
# |    n_updates        | 4272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.174    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1449     |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 208524   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0661   |
# |    n_updates        | 4342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.167    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1434     |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 210300   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.388    |
# |    n_updates        | 4379     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.164    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1415     |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 211176   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.387    |
# |    n_updates        | 4397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1402     |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 213072   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0572   |
# |    n_updates        | 4436     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.154    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1383     |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 213744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0477   |
# |    n_updates        | 4450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.148    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1368     |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 215076   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 4478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.134    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1364     |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 218616   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 4552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.131    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1348     |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 219504   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.719    |
# |    n_updates        | 4570     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.126    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1333     |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 220596   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0337   |
# |    n_updates        | 4593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.121    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1324     |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 221892   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.399    |
# |    n_updates        | 4620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.117    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1310     |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 222996   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.328    |
# |    n_updates        | 4643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.108    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1301     |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 225192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0363   |
# |    n_updates        | 4689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0967   |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1296     |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 228108   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0606   |
# |    n_updates        | 4750     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0893   |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1287     |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 229968   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0409   |
# |    n_updates        | 4788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0833   |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1277     |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 231492   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0412   |
# |    n_updates        | 4820     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0746   |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1271     |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 233688   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0721   |
# |    n_updates        | 4866     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0697   |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1259     |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 234924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.267    |
# |    n_updates        | 4892     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0669   |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1250     |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 235620   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.543    |
# |    n_updates        | 4906     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0591   |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1244     |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 237600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0463   |
# |    n_updates        | 4947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0569   |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1231     |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 238152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0358   |
# |    n_updates        | 4959     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0518   |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1221     |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 239448   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0553   |
# |    n_updates        | 4986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0504   |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1207     |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 239796   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0308   |
# |    n_updates        | 4993     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0466   |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1196     |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 240756   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0534   |
# |    n_updates        | 5013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0394   |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1189     |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 242580   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.037    |
# |    n_updates        | 5051     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0344   |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1180     |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 243828   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0384   |
# |    n_updates        | 5077     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0296   |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1170     |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 245040   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0337   |
# |    n_updates        | 5102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.022    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1164     |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 246972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0469   |
# |    n_updates        | 5143     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0165   |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1156     |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 248352   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.497    |
# |    n_updates        | 5171     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0113   |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1148     |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 249660   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0372   |
# |    n_updates        | 5199     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1141     |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 251196   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0426   |
# |    n_updates        | 5231     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1138     |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 253560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0353   |
# |    n_updates        | 5280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1129     |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 254652   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0336   |
# |    n_updates        | 5303     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1122     |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 255972   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.749    |
# |    n_updates        | 5330     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1114     |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 257124   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0501   |
# |    n_updates        | 5354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1105     |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 257796   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.373    |
# |    n_updates        | 5368     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1100     |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 259908   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.29     |
# |    n_updates        | 5412     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1091     |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 260568   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 5426     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1087     |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 262560   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.429    |
# |    n_updates        | 5467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1078     |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 263088   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 5478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1071     |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 264312   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0353   |
# |    n_updates        | 5504     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1065     |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 265476   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.393    |
# |    n_updates        | 5528     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1060     |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 267384   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0319   |
# |    n_updates        | 5568     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 141      |
# |    time_elapsed     | 3098     |
# |    total_timesteps  | 437268   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 40352    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 141      |
# |    time_elapsed     | 3100     |
# |    total_timesteps  | 438048   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0359   |
# |    n_updates        | 40368    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 141      |
# |    time_elapsed     | 3103     |
# |    total_timesteps  | 440388   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 40417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 142      |
# |    time_elapsed     | 3106     |
# |    total_timesteps  | 441168   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 40433    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 142      |
# |    time_elapsed     | 3109     |
# |    total_timesteps  | 442152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 40454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 142      |
# |    time_elapsed     | 3111     |
# |    total_timesteps  | 443172   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.256    |
# |    n_updates        | 40475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 142      |
# |    time_elapsed     | 3114     |
# |    total_timesteps  | 444828   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0222   |
# |    n_updates        | 40510    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 142      |
# |    time_elapsed     | 3117     |
# |    total_timesteps  | 445752   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 40529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 143      |
# |    time_elapsed     | 3120     |
# |    total_timesteps  | 447924   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 40574    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 143      |
# |    time_elapsed     | 3123     |
# |    total_timesteps  | 449412   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 40605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 143      |
# |    time_elapsed     | 3125     |
# |    total_timesteps  | 449640   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00769  |
# |    n_updates        | 40610    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 144      |
# |    time_elapsed     | 3128     |
# |    total_timesteps  | 451836   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 40656    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 144      |
# |    time_elapsed     | 3131     |
# |    total_timesteps  | 452592   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0179   |
# |    n_updates        | 40671    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 144      |
# |    time_elapsed     | 3133     |
# |    total_timesteps  | 453912   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0111   |
# |    n_updates        | 40699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 144      |
# |    time_elapsed     | 3136     |
# |    total_timesteps  | 454692   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 40715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 145      |
# |    time_elapsed     | 3139     |
# |    total_timesteps  | 456168   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.38     |
# |    n_updates        | 40746    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 145      |
# |    time_elapsed     | 3141     |
# |    total_timesteps  | 457344   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.36     |
# |    n_updates        | 40770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 145      |
# |    time_elapsed     | 3144     |
# |    total_timesteps  | 458472   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.319    |
# |    n_updates        | 40794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 146      |
# |    time_elapsed     | 3147     |
# |    total_timesteps  | 460236   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.348    |
# |    n_updates        | 40831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 146      |
# |    time_elapsed     | 3150     |
# |    total_timesteps  | 460656   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 40839    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 146      |
# |    time_elapsed     | 3152     |
# |    total_timesteps  | 461940   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.366    |
# |    n_updates        | 40866    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 146      |
# |    time_elapsed     | 3155     |
# |    total_timesteps  | 463116   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.291    |
# |    n_updates        | 40891    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 147      |
# |    time_elapsed     | 3158     |
# |    total_timesteps  | 464532   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 40920    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 147      |
# |    time_elapsed     | 3160     |
# |    total_timesteps  | 465012   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 40930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 147      |
# |    time_elapsed     | 3163     |
# |    total_timesteps  | 466716   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 40966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 147      |
# |    time_elapsed     | 3166     |
# |    total_timesteps  | 467808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 40988    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 148      |
# |    time_elapsed     | 3169     |
# |    total_timesteps  | 469404   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 41022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 148      |
# |    time_elapsed     | 3172     |
# |    total_timesteps  | 470988   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 41055    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 148      |
# |    time_elapsed     | 3175     |
# |    total_timesteps  | 471684   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00891  |
# |    n_updates        | 41069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 148      |
# |    time_elapsed     | 3178     |
# |    total_timesteps  | 473376   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.367    |
# |    n_updates        | 41104    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 149      |
# |    time_elapsed     | 3180     |
# |    total_timesteps  | 474420   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.484    |
# |    n_updates        | 41126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 149      |
# |    time_elapsed     | 3183     |
# |    total_timesteps  | 475368   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.614    |
# |    n_updates        | 41146    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 149      |
# |    time_elapsed     | 3186     |
# |    total_timesteps  | 475860   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 41156    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 149      |
# |    time_elapsed     | 3188     |
# |    total_timesteps  | 476676   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0358   |
# |    n_updates        | 41173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 149      |
# |    time_elapsed     | 3191     |
# |    total_timesteps  | 477204   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 41184    |
# ----------------------------------
# Training Interrupted

# %%
save_path = "./models/dqn_step-rewards_a3"

# %%
# Load and resume training from saved model
try:
    model.load(path = save_path, env = env)
    # model.exploration_initial_eps = 0.6
    # model.exploration_final_eps = 0.01
    # model.exploration_fraction = 0.1
    # model.learnin_rate = 0.0001
    model.learn(total_timesteps=10000000, reset_num_timesteps=False, progress_bar=False)
    model.save(save_path)
except KeyboardInterrupt:
    print("Training Interrupted")
    print("Saving Model")
    model.save(save_path)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 612      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 480840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 41947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 632      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 484840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 42947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 648      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 488840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 43947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 660      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 492840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 44947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 648      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 496840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 45947    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 637      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 499864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00937  |
# |    n_updates        | 46703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 648      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 503864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 47703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.904    |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 656      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 507864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 48703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 663      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 511864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 49703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 668      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 515864   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 50703    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 665      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 518923   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00301  |
# |    n_updates        | 51468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 669      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 522923   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.722    |
# |    n_updates        | 52468    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 669      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 526804   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00873  |
# |    n_updates        | 53438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.9      |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 668      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 530422   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 54343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 671      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 534422   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 55343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 673      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 538422   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 56343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 1304     |
# |    fps              | 675      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 542422   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00832  |
# |    n_updates        | 57343    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 1308     |
# |    fps              | 675      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 546023   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00547  |
# |    n_updates        | 58243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 1312     |
# |    fps              | 676      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 550023   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00941  |
# |    n_updates        | 59243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 1316     |
# |    fps              | 678      |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 554023   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 60243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 680      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 558023   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 61243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 1324     |
# |    fps              | 679      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 561916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0143   |
# |    n_updates        | 62216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 1328     |
# |    fps              | 680      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 565916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.357    |
# |    n_updates        | 63216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 1332     |
# |    fps              | 678      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 568917   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0214   |
# |    n_updates        | 63967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 1336     |
# |    fps              | 678      |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 572820   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 64942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 679      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 576820   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 65942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 1344     |
# |    fps              | 680      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 580820   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 66942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 1348     |
# |    fps              | 681      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 584820   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 67942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 1352     |
# |    fps              | 682      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 588820   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 68942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 1356     |
# |    fps              | 682      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 592748   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00842  |
# |    n_updates        | 69924    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 681      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 596316   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0329   |
# |    n_updates        | 70816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 678      |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 599973   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 71731    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 677      |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 603233   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 72546    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 678      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 607233   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 73546    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 677      |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 610503   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 74363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 678      |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 614503   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 75363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 678      |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 618503   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 76363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 679      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 622503   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.424    |
# |    n_updates        | 77363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 678      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 625808   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00851  |
# |    n_updates        | 78189    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 678      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 629725   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 79169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 677      |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 632845   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00841  |
# |    n_updates        | 79949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 677      |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 636845   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 80949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 676      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 640131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 81770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 677      |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 644131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00933  |
# |    n_updates        | 82770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 678      |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 648131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0072   |
# |    n_updates        | 83770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 678      |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 652131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00384  |
# |    n_updates        | 84770    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 678      |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 655826   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00662  |
# |    n_updates        | 85694    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 677      |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 659318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00845  |
# |    n_updates        | 86567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 678      |
# |    time_elapsed     | 273      |
# |    total_timesteps  | 663318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0067   |
# |    n_updates        | 87567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 679      |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 667318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 88567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 680      |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 671318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 89567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 680      |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 675318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 90567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 681      |
# |    time_elapsed     | 295      |
# |    total_timesteps  | 679318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00583  |
# |    n_updates        | 91567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 680      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 683302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 92563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 681      |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 687302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00696  |
# |    n_updates        | 93563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 681      |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 691302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 94563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 1464     |
# |    fps              | 682      |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 695302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00893  |
# |    n_updates        | 95563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 682      |
# |    time_elapsed     | 324      |
# |    total_timesteps  | 699302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 96563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.867    |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 682      |
# |    time_elapsed     | 330      |
# |    total_timesteps  | 703302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.445    |
# |    n_updates        | 97563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 681      |
# |    time_elapsed     | 335      |
# |    total_timesteps  | 706794   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 98436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 1480     |
# |    fps              | 682      |
# |    time_elapsed     | 341      |
# |    total_timesteps  | 710794   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 99436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 1484     |
# |    fps              | 682      |
# |    time_elapsed     | 347      |
# |    total_timesteps  | 714794   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00944  |
# |    n_updates        | 100436   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 1488     |
# |    fps              | 681      |
# |    time_elapsed     | 352      |
# |    total_timesteps  | 718250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 101300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 1492     |
# |    fps              | 681      |
# |    time_elapsed     | 358      |
# |    total_timesteps  | 722250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0279   |
# |    n_updates        | 102300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 1496     |
# |    fps              | 682      |
# |    time_elapsed     | 364      |
# |    total_timesteps  | 726250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0187   |
# |    n_updates        | 103300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 1500     |
# |    fps              | 682      |
# |    time_elapsed     | 369      |
# |    total_timesteps  | 730250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.438    |
# |    n_updates        | 104300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 1504     |
# |    fps              | 682      |
# |    time_elapsed     | 375      |
# |    total_timesteps  | 734250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 105300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 1508     |
# |    fps              | 683      |
# |    time_elapsed     | 381      |
# |    total_timesteps  | 738250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00884  |
# |    n_updates        | 106300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 1512     |
# |    fps              | 683      |
# |    time_elapsed     | 386      |
# |    total_timesteps  | 742250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00682  |
# |    n_updates        | 107300   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 1516     |
# |    fps              | 681      |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 744461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.309    |
# |    n_updates        | 107853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 1520     |
# |    fps              | 681      |
# |    time_elapsed     | 397      |
# |    total_timesteps  | 748461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00638  |
# |    n_updates        | 108853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 1524     |
# |    fps              | 681      |
# |    time_elapsed     | 402      |
# |    total_timesteps  | 752461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00768  |
# |    n_updates        | 109853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 1528     |
# |    fps              | 681      |
# |    time_elapsed     | 408      |
# |    total_timesteps  | 756461   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00569  |
# |    n_updates        | 110853   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 1532     |
# |    fps              | 681      |
# |    time_elapsed     | 414      |
# |    total_timesteps  | 760389   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00905  |
# |    n_updates        | 111835   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 1536     |
# |    fps              | 681      |
# |    time_elapsed     | 419      |
# |    total_timesteps  | 763927   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00803  |
# |    n_updates        | 112719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 1540     |
# |    fps              | 681      |
# |    time_elapsed     | 425      |
# |    total_timesteps  | 767927   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00666  |
# |    n_updates        | 113719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 1544     |
# |    fps              | 681      |
# |    time_elapsed     | 431      |
# |    total_timesteps  | 771927   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0115   |
# |    n_updates        | 114719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 1548     |
# |    fps              | 681      |
# |    time_elapsed     | 437      |
# |    total_timesteps  | 775631   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 115645   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 1552     |
# |    fps              | 680      |
# |    time_elapsed     | 443      |
# |    total_timesteps  | 779482   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 116608   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 1556     |
# |    fps              | 680      |
# |    time_elapsed     | 448      |
# |    total_timesteps  | 783482   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 117608   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 1560     |
# |    fps              | 679      |
# |    time_elapsed     | 453      |
# |    total_timesteps  | 786100   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 118262   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 1564     |
# |    fps              | 679      |
# |    time_elapsed     | 459      |
# |    total_timesteps  | 790100   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 119262   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 1568     |
# |    fps              | 679      |
# |    time_elapsed     | 464      |
# |    total_timesteps  | 793439   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 120097   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 1572     |
# |    fps              | 679      |
# |    time_elapsed     | 470      |
# |    total_timesteps  | 797439   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.358    |
# |    n_updates        | 121097   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 1576     |
# |    fps              | 679      |
# |    time_elapsed     | 476      |
# |    total_timesteps  | 801439   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00432  |
# |    n_updates        | 122097   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 1580     |
# |    fps              | 678      |
# |    time_elapsed     | 481      |
# |    total_timesteps  | 804265   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00352  |
# |    n_updates        | 122804   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 1584     |
# |    fps              | 677      |
# |    time_elapsed     | 486      |
# |    total_timesteps  | 807441   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0122   |
# |    n_updates        | 123598   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 1588     |
# |    fps              | 676      |
# |    time_elapsed     | 492      |
# |    total_timesteps  | 811406   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 124589   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 1592     |
# |    fps              | 677      |
# |    time_elapsed     | 498      |
# |    total_timesteps  | 815406   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 125589   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 1596     |
# |    fps              | 676      |
# |    time_elapsed     | 504      |
# |    total_timesteps  | 819292   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.032    |
# |    n_updates        | 126560   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.845    |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 676      |
# |    time_elapsed     | 509      |
# |    total_timesteps  | 822293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.464    |
# |    n_updates        | 127311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 1604     |
# |    fps              | 675      |
# |    time_elapsed     | 515      |
# |    total_timesteps  | 826293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 128311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 1608     |
# |    fps              | 675      |
# |    time_elapsed     | 521      |
# |    total_timesteps  | 830293   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 129311   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 1612     |
# |    fps              | 674      |
# |    time_elapsed     | 527      |
# |    total_timesteps  | 833930   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 130220   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 1616     |
# |    fps              | 673      |
# |    time_elapsed     | 532      |
# |    total_timesteps  | 836931   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00952  |
# |    n_updates        | 130970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 1620     |
# |    fps              | 674      |
# |    time_elapsed     | 538      |
# |    total_timesteps  | 840931   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 131970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 1624     |
# |    fps              | 674      |
# |    time_elapsed     | 544      |
# |    total_timesteps  | 844931   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0199   |
# |    n_updates        | 132970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 1628     |
# |    fps              | 674      |
# |    time_elapsed     | 550      |
# |    total_timesteps  | 848931   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0117   |
# |    n_updates        | 133970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 1632     |
# |    fps              | 674      |
# |    time_elapsed     | 556      |
# |    total_timesteps  | 852931   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 134970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 1636     |
# |    fps              | 674      |
# |    time_elapsed     | 562      |
# |    total_timesteps  | 856896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0243   |
# |    n_updates        | 135961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 1640     |
# |    fps              | 674      |
# |    time_elapsed     | 567      |
# |    total_timesteps  | 860896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0191   |
# |    n_updates        | 136961   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 1644     |
# |    fps              | 674      |
# |    time_elapsed     | 573      |
# |    total_timesteps  | 864738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 137922   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 1648     |
# |    fps              | 674      |
# |    time_elapsed     | 579      |
# |    total_timesteps  | 868738   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 138922   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 1652     |
# |    fps              | 673      |
# |    time_elapsed     | 584      |
# |    total_timesteps  | 871459   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0178   |
# |    n_updates        | 139602   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 1656     |
# |    fps              | 673      |
# |    time_elapsed     | 590      |
# |    total_timesteps  | 875375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.314    |
# |    n_updates        | 140581   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 1660     |
# |    fps              | 672      |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 3992     |
# |    fps              | 556      |
# |    time_elapsed     | 3731     |
# |    total_timesteps  | 2553669  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.333    |
# |    n_updates        | 560155   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 3996     |
# |    fps              | 556      |
# |    time_elapsed     | 3735     |
# |    total_timesteps  | 2555343  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00474  |
# |    n_updates        | 560573   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 4000     |
# |    fps              | 556      |
# |    time_elapsed     | 3740     |
# |    total_timesteps  | 2557671  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00416  |
# |    n_updates        | 561155   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 4004     |
# |    fps              | 555      |
# |    time_elapsed     | 3745     |
# |    total_timesteps  | 2560021  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00694  |
# |    n_updates        | 561743   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 4008     |
# |    fps              | 555      |
# |    time_elapsed     | 3749     |
# |    total_timesteps  | 2562225  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00507  |
# |    n_updates        | 562294   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 4012     |
# |    fps              | 555      |
# |    time_elapsed     | 3754     |
# |    total_timesteps  | 2564421  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.33     |
# |    n_updates        | 562843   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 4016     |
# |    fps              | 555      |
# |    time_elapsed     | 3759     |
# |    total_timesteps  | 2566839  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.309    |
# |    n_updates        | 563447   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.515    |
# | time/               |          |
# |    episodes         | 4020     |
# |    fps              | 555      |
# |    time_elapsed     | 3764     |
# |    total_timesteps  | 2569011  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 563990   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 4024     |
# |    fps              | 555      |
# |    time_elapsed     | 3769     |
# |    total_timesteps  | 2571211  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 564540   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 4028     |
# |    fps              | 555      |
# |    time_elapsed     | 3774     |
# |    total_timesteps  | 2573307  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 565064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 4032     |
# |    fps              | 555      |
# |    time_elapsed     | 3779     |
# |    total_timesteps  | 2575779  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.701    |
# |    n_updates        | 565682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.513    |
# | time/               |          |
# |    episodes         | 4036     |
# |    fps              | 554      |
# |    time_elapsed     | 3784     |
# |    total_timesteps  | 2578026  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 566244   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 4040     |
# |    fps              | 554      |
# |    time_elapsed     | 3790     |
# |    total_timesteps  | 2581021  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.235    |
# |    n_updates        | 566993   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 4044     |
# |    fps              | 554      |
# |    time_elapsed     | 3795     |
# |    total_timesteps  | 2583447  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 567599   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 4048     |
# |    fps              | 554      |
# |    time_elapsed     | 3799     |
# |    total_timesteps  | 2585139  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0122   |
# |    n_updates        | 568022   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 4052     |
# |    fps              | 554      |
# |    time_elapsed     | 3805     |
# |    total_timesteps  | 2587959  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 568727   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 4056     |
# |    fps              | 554      |
# |    time_elapsed     | 3810     |
# |    total_timesteps  | 2590582  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.271    |
# |    n_updates        | 569383   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 4060     |
# |    fps              | 554      |
# |    time_elapsed     | 3815     |
# |    total_timesteps  | 2592684  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 569908   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 4064     |
# |    fps              | 554      |
# |    time_elapsed     | 3820     |
# |    total_timesteps  | 2594896  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0101   |
# |    n_updates        | 570461   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 4068     |
# |    fps              | 553      |
# |    time_elapsed     | 3825     |
# |    total_timesteps  | 2597002  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0116   |
# |    n_updates        | 570988   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 4072     |
# |    fps              | 553      |
# |    time_elapsed     | 3829     |
# |    total_timesteps  | 2598613  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00914  |
# |    n_updates        | 571391   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.509    |
# | time/               |          |
# |    episodes         | 4076     |
# |    fps              | 553      |
# |    time_elapsed     | 3834     |
# |    total_timesteps  | 2600601  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00921  |
# |    n_updates        | 571888   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 4080     |
# |    fps              | 553      |
# |    time_elapsed     | 3839     |
# |    total_timesteps  | 2603276  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.016    |
# |    n_updates        | 572556   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 4084     |
# |    fps              | 553      |
# |    time_elapsed     | 3843     |
# |    total_timesteps  | 2604252  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00453  |
# |    n_updates        | 572800   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 4088     |
# |    fps              | 553      |
# |    time_elapsed     | 3848     |
# |    total_timesteps  | 2606401  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.359    |
# |    n_updates        | 573338   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 4092     |
# |    fps              | 553      |
# |    time_elapsed     | 3853     |
# |    total_timesteps  | 2609002  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.298    |
# |    n_updates        | 573988   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.507    |
# | time/               |          |
# |    episodes         | 4096     |
# |    fps              | 552      |
# |    time_elapsed     | 3857     |
# |    total_timesteps  | 2610371  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00886  |
# |    n_updates        | 574330   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 4100     |
# |    fps              | 552      |
# |    time_elapsed     | 3861     |
# |    total_timesteps  | 2612167  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 574779   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 4104     |
# |    fps              | 552      |
# |    time_elapsed     | 3866     |
# |    total_timesteps  | 2613922  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.006    |
# |    n_updates        | 575218   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 4108     |
# |    fps              | 552      |
# |    time_elapsed     | 3871     |
# |    total_timesteps  | 2616932  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.322    |
# |    n_updates        | 575970   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 4112     |
# |    fps              | 552      |
# |    time_elapsed     | 3876     |
# |    total_timesteps  | 2618781  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.301    |
# |    n_updates        | 576433   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    episodes         | 4116     |
# |    fps              | 552      |
# |    time_elapsed     | 3881     |
# |    total_timesteps  | 2620599  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 576887   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 4120     |
# |    fps              | 551      |
# |    time_elapsed     | 3886     |
# |    total_timesteps  | 2623195  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00643  |
# |    n_updates        | 577536   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 4124     |
# |    fps              | 551      |
# |    time_elapsed     | 3892     |
# |    total_timesteps  | 2626545  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.008    |
# |    n_updates        | 578374   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.503    |
# | time/               |          |
# |    episodes         | 4128     |
# |    fps              | 551      |
# |    time_elapsed     | 3898     |
# |    total_timesteps  | 2628908  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00827  |
# |    n_updates        | 578964   |
# ----------------------------------
# Training Interrupted
# Saving Model

# %%
# Evaluate the model
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=1)
print(f"Mean Reward: {mean_reward}, Std Reward: {std_reward}")
# Out:
# Mean Reward: 0.48489999771118164, Std Reward: 0.0

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
# save_path = "./models/dqn_intelligoal_a1_works-100"
# save_path = "models\dqn_step-rewards_a2-good-stuff.zip"

save_path = "./models/dqn_step-rewards_a3-best_static_goals"
device = "cuda"

# %%
def make_env():
    def _init():
        env = IntelliGoal()
        env.render_mode = 'human'
        return env
    return _init

# Wrap your environment in a DummyVecEnv for compatibility
env = DummyVecEnv([make_env()])

model = DQN.load(save_path, env=env, device=device)

def run_model():
    obs = env.reset()  # This will now be in the correct batch format
    done = False
    while True:
        action, _states = model.predict(obs, deterministic=True)
        obs, rewards, done, info = env.step(action)
        env.render()
        if done:
            print("Episode Finished with Reward - ", rewards[0])
            obs = env.reset()

try:
    run_model()
except:
    print("Environment Closed")
# Out:
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  -0.7
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Episode Finished with Reward -  0.5
# Environment Closed

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
