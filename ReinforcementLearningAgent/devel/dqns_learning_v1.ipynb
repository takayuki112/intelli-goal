# %%
import pygame
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import math
import random
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
class IntelliGoal(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(s):
        super(IntelliGoal, s).__init__()
        
        s.screen_width = 1240
        s.screen_height = 800
        s.border_width = 10
        s.screen = None
        
        s.goal_radius = 20
        s.player_radius = 10
        
        s.player_speed = 1
        
        
        # State information
        s.player_x = 0
        s.player_y = 0
        s.goal_x = 0
        s.goal_y = 0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        s.reward = 0
        
        s.done = False
        s.trucated = False
        s.truncation_step_limit = 500
        s.truncation_step_counter = 0
        s.goal_spawn_range = 100
        
        
        # State and Action spaces
        s.action_space = spaces.Discrete(5) # 0: No movement, 1: Up, 2: Down, 3: Left, 4: Right
        # observation space = [player_x, player_y, goal_x, goal_y]
        s.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 0]), 
            high=np.array([s.screen_width, s.screen_height, s.screen_width, s.screen_height]), 
            dtype=np.int32
        )
    
    def seed(s, seed=None):
        if seed is not None and (seed < 0 or seed >= 2**32):
            raise ValueError("Seed must be between 0 and 2**32 - 1")
        s.np_random, seed = gym.utils.seeding.np_random(seed)
        return [seed]
        
    def reset(s, seed=0):
        s.seed(seed)
        
        s.player_x = s.screen_width // 2
        s.player_y = s.screen_height // 2
        
        s.goal_x, s.goal_y = s.respawn_goal()
        
        s.reward = 0
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        
        s.done = False
        s.trucated = False
        s.truncation_step_counter = 0
        
        return s.state, {}
    
    def respawn_goal(s):
        s.goal_x = s.player_x + random.randint(-s.goal_spawn_range, s.goal_spawn_range)
        s.goal_y = s.player_y + random.randint(-s.goal_spawn_range, s.goal_spawn_range)
        
        # clip the goal to the screen
        offset = s.border_width + s.goal_radius
        s.goal_x = min( max(s.goal_x, offset), s.screen_width - offset)
        s.goal_y = min( max(s.goal_y, offset), s.screen_height - offset)
        
        pygame.time.wait(300)
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        return s.goal_x, s.goal_y
        
    def step(s, action):
        #################
        #do more here?
        #################
        
        s.do_action(action)
        s.calculate_reward()
        
        s.truncation_step_counter += 1
        if s.truncation_step_counter >= s.truncation_step_limit:
            s.reward -= 0.4
            s.trucated = True
            s.done = True

        if s.reward < -1:
            s.reward = -1
            s.trucated = False
        
        if s.reward > 1:
            s.reward = 1
        
        
        return s.state, s.reward, s.done, s.trucated, {}
        
   
    def do_action(s, action):
        if not s.action_space.contains(action):
            print("Invalid Action")
        
        s.prev_distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)
        
        s.player_x += (action == 4)*s.player_speed - (action == 3)*s.player_speed 
        s.player_y += (action == 2)*s.player_speed - (action == 1)*s.player_speed
        
    def calculate_reward(s):
        # Distance between player and goal
        distance = math.sqrt((s.player_x - s.goal_x) ** 2 + (s.player_y - s.goal_y) ** 2)

        # Check if the red dot touches the border
        if s.player_x not in range(s.border_width, s.screen_width - s.border_width) or s.player_y not in range(s.border_width, s.screen_height - s.border_width):
            s.player_x, s.player_y = s.screen_width // 2, s.screen_height // 2

        # Check if the goal is reached within a certain range
        if distance < s.goal_radius + s.player_radius:
            s.goal_x, s.goal_y = s.respawn_goal()
            s.reward += 1
            s.done = True  
    
        s.state = np.array([s.player_x, s.player_y, s.goal_x, s.goal_y])
        
        # Reward the agent for getting closer to the goal
        if s.prev_distance > distance:
            s.reward += 0.010
        if s.prev_distance < distance:
            s.reward -= 0.015
        
        # Penalize the agent for taking too long
        s.reward -= 0.0001
     
    
    def keyboard_input(s):
        keys = pygame.key.get_pressed()
        # 1: Up, 2: Down, 3: Left, 4: Right
        if keys[pygame.K_UP]:
            return 1
        if keys[pygame.K_DOWN]:
            return 2
        if keys[pygame.K_LEFT]:
            return 3
        if keys[pygame.K_RIGHT]:
            return 4
        return 0
        
    
    def render(s, mode = 'human'):
        if s.screen == None:
            pygame.init()
            s.screen = pygame.display.set_mode((s.screen_width, s.screen_height))
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
        s.player_x, s.player_y, s.goal_x, s.goal_y = s.state
        
        s.screen.fill((0, 0, 0))
        RED = (255, 0, 0)
        BLUE = (0, 0, 255)
        BORDER_COLOR = (255, 255, 0)
        
        # Draw the border
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, 0, s.border_width, s.screen_height))
        pygame.draw.rect(s.screen, BORDER_COLOR, (0, s.screen_height - s.border_width, s.screen_width, s.border_width))
        pygame.draw.rect(s.screen, BORDER_COLOR, (s.screen_width - s.border_width, 0, s.border_width, s.screen_height))

        # Draw the red dot
        pygame.draw.circle(s.screen, RED, (s.player_x, s.player_y), 10)

        # Draw the blue dot
        pygame.draw.circle(s.screen, BLUE, (s.goal_x, s.goal_y), s.goal_radius)
        
        #Display Reward on pygame screen
        font = pygame.font.Font(None, 36)
        text = font.render("Reward: " + str(round(s.reward, 5)), True, (255, 255, 255))
        s.screen.blit(text, (10, 10))
        
        pygame.display.update()
    
    def close(s):
        pygame.quit()

# %%
# Test Env with keyboard input actions
test_env = IntelliGoal()
test_env.reset(0)
done = False
i = 1

while True:
    try:
        test_env.render()
        action = test_env.keyboard_input()
        state, reward, done, truncated, _i = test_env.step(action)
        if done or truncated:
            print("Reward at step - ", i, " : ", round(reward, 5))
            i += 1
            test_env.reset(0)
    except:
        print("Environment Closed")
        break

while True:
    test_env.render()
    action = test_env.keyboard_input()
    state, reward, done, truncated, _i = test_env.step(action)
    if done or truncated:
        print("Reward at step - ", i, " : ", round(reward, 5))
        i += 1
        test_env.reset(0)   

test_env.close()
# Out:
# Reward at step -  1  :  -0.45
# Reward at step -  2  :  -0.45
# Reward at step -  3  :  -0.45
# Reward at step -  4  :  -0.45
# Reward at step -  5  :  -0.45
# Reward at step -  6  :  -0.45
# Reward at step -  7  :  -0.45
# Reward at step -  8  :  -0.45
# Reward at step -  9  :  -0.9941
# Reward at step -  10  :  1
# Reward at step -  11  :  1
# Reward at step -  12  :  1
# Reward at step -  13  :  -1
# Reward at step -  14  :  -1
# Reward at step -  15  :  -1
# Reward at step -  16  :  0.6099
# Reward at step -  17  :  1
# Reward at step -  18  :  -1
# Reward at step -  19  :  1
# Reward at step -  20  :  1
# Reward at step -  21  :  -0.509
# Reward at step -  22  :  1
# Reward at step -  23  :  -0.5189
# Reward at step -  24  :  1
# Reward at step -  25  :  -0.5485
# Reward at step -  26  :  0.3472
# Reward at step -  27  :  0.6099
# Reward at step -  28  :  0.5615
# Reward at step -  29  :  0.6099
# Reward at step -  30  :  1
# Reward at step -  31  :  1
# Reward at step -  32  :  -1
# Reward at step -  33  :  0.3092
# Reward at step -  34  :  0.6099
# Reward at step -  35  :  0.6099
# Reward at step -  36  :  -1
# Reward at step -  37  :  -0.45
# Reward at step -  38  :  -0.45
# Environment Closed
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[25], line 21
#      18         break
#      20 while True:
# ---> 21     test_env.render()
#      22     action = test_env.keyboard_input()
#      23     state, reward, done, truncated, _i = test_env.step(action)
#
# Cell In[24], line 160, in IntelliGoal.render(s, mode)
#     158     pygame.init()
#     159     s.screen = pygame.display.set_mode((s.screen_width, s.screen_height))
# --> 160 for event in pygame.event.get():
#     161     if event.type == pygame.QUIT:
#     162         pygame.quit()
#
# error: video system not initialized

# %% [markdown]
# # DQN Learning Algorithm

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
import torch
device = "cpu"
if torch.cuda.is_available():
    device = "cuda"
    print("Using GPU - ", torch.cuda.get_device_name(0))
# Out:
# Using GPU -  NVIDIA RTX A500 Laptop GPU

# %%
env = IntelliGoal()
check_env(env)

# %%
def make_env():
    env = IntelliGoal()
    return env

num_envs = 2
take_logs = False
device = "cuda"

if take_logs:
    log_dir = "./logs/ppo_intelligoal_a3_explore-more"
else:
    log_dir = None
      
if num_envs == 1:
    env = DummyVecEnv([make_env] * num_envs)
else:
    env = SubprocVecEnv([make_env] * num_envs)


# model = PPO("MlpPolicy", env, verbose=1, device=device)

# Define DQN model with specific parameters
model = DQN("MlpPolicy", env, verbose=1, 
            buffer_size=10000, 
            learning_rate=0.0005, 
            batch_size=32, 
            tau=1.0, 
            gamma=0.99, 
            train_freq=4, 
            gradient_steps=1, 
            exploration_fraction=0.1, 
            exploration_final_eps=0.01, 
            target_update_interval=1000, 
            max_grad_norm=10, 
            tensorboard_log="./logs/dqn_intelligoal_tensorboard/", 
            device=device)
# Out:
# Using cuda device

# %%
save_path = "./models/dqn_intelligoal_a1"

# %%
# Start New training session
# save_path = "./models/intelli_goal_a2"
# # set teh goal to spawn close - +_ 50 pixels initially

# if os.path.exists(save_path +".zip"):
#     #append number to the file name
#     i = save_path[-1]
#     i = int(i) + 1
#     save_path = save_path[:-1] + str(i)
#     print("Model already exists. Saving new one as - ", save_path)
    
# try:
#     model.learn(total_timesteps=9999999999)
#     model.save(save_path)
# except KeyboardInterrupt:
#     print("Training Interrupted")
#     model.save(save_path)
# Out:
# Logging to ./logs/dqn_intelligoal_tensorboard/DQN_4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 237      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 604      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.728    |
# |    n_updates        | 63       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 262      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 1428     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.759    |
# |    n_updates        | 166      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 291      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 2242     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.945    |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 328      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 3386     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.274    |
# |    n_updates        | 411      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 288      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 3652     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.523    |
# |    n_updates        | 444      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 271      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 4128     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.177    |
# |    n_updates        | 503      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 279      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 4982     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.57     |
# |    n_updates        | 610      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 277      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 5586     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.331    |
# |    n_updates        | 686      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 274      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 6188     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.435    |
# |    n_updates        | 761      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 255      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 6334     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.93     |
# |    n_updates        | 779      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 272      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 7534     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.43     |
# |    n_updates        | 929      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 271      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 8138     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.58     |
# |    n_updates        | 1005     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 271      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 8778     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.349    |
# |    n_updates        | 1085     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 258      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 8932     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.588    |
# |    n_updates        | 1104     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 255      |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 9536     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.294    |
# |    n_updates        | 1179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 262      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 10390    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.582    |
# |    n_updates        | 1286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 261      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 10992    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.62     |
# |    n_updates        | 1361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 265      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 11858    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0825   |
# |    n_updates        | 1470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 265      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 12498    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 1550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 266      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 13140    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.427    |
# |    n_updates        | 1630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 278      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 14340    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.541    |
# |    n_updates        | 1780     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 288      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 15540    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.272    |
# |    n_updates        | 1930     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 285      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 16100    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.247    |
# |    n_updates        | 2000     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 280      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 16574    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.423    |
# |    n_updates        | 2059     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 287      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 17702    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.163    |
# |    n_updates        | 2200     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 296      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 18902    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0876   |
# |    n_updates        | 2350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 295      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 19504    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.207    |
# |    n_updates        | 2425     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 293      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 20104    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.544    |
# |    n_updates        | 2500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 294      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 20934    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.576    |
# |    n_updates        | 2604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 298      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 22110    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.54     |
# |    n_updates        | 2751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 297      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 22864    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.57     |
# |    n_updates        | 2845     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 295      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 23490    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 2924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 292      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 24068    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.219    |
# |    n_updates        | 2996     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 290      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 24670    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.432    |
# |    n_updates        | 3071     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 286      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 25028    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.325    |
# |    n_updates        | 3116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 288      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 25942    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.148    |
# |    n_updates        | 3230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 289      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 26830    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.349    |
# |    n_updates        | 3341     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 291      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 27746    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.35     |
# |    n_updates        | 3456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 292      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 28630    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.41     |
# |    n_updates        | 3566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 292      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 29344    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.325    |
# |    n_updates        | 3655     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 291      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 30086    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.633    |
# |    n_updates        | 3748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 295      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 31286    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.151    |
# |    n_updates        | 3898     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 292      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 31754    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.25     |
# |    n_updates        | 3957     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 293      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 32488    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.674    |
# |    n_updates        | 4048     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 295      |
# |    time_elapsed     | 113      |
# |    total_timesteps  | 33542    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.171    |
# |    n_updates        | 4180     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 295      |
# |    time_elapsed     | 116      |
# |    total_timesteps  | 34290    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.237    |
# |    n_updates        | 4274     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 297      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 35344    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.074    |
# |    n_updates        | 4405     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 294      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 35852    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.395    |
# |    n_updates        | 4469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 294      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 36546    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.316    |
# |    n_updates        | 4556     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 293      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 37182    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.191    |
# |    n_updates        | 4635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 296      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 38364    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.14     |
# |    n_updates        | 4783     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 298      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 39504    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.401    |
# |    n_updates        | 4925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 299      |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 40164    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.1      |
# |    n_updates        | 5008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 298      |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 40766    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.14     |
# |    n_updates        | 5083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 302      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 41966    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.318    |
# |    n_updates        | 5233     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 301      |
# |    time_elapsed     | 141      |
# |    total_timesteps  | 42718    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.113    |
# |    n_updates        | 5327     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 300      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 43342    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 2.02     |
# |    n_updates        | 5405     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 300      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 44126    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.206    |
# |    n_updates        | 5503     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 299      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 44726    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.297    |
# |    n_updates        | 5578     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 300      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 45668    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.139    |
# |    n_updates        | 5696     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 301      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 46586    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 5811     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 302      |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 47624    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.26     |
# |    n_updates        | 5940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 303      |
# |    time_elapsed     | 160      |
# |    total_timesteps  | 48740    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.198    |
# |    n_updates        | 6080     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 304      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 49714    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0914   |
# |    n_updates        | 6202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 304      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 50542    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 6305     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 303      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 51144    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.365    |
# |    n_updates        | 6380     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 302      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 51746    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.239    |
# |    n_updates        | 6456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 304      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 52848    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.204    |
# |    n_updates        | 6593     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 304      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 53548    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 4.12     |
# |    n_updates        | 6681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 306      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 54650    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.469    |
# |    n_updates        | 6819     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 305      |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 55272    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0808   |
# |    n_updates        | 6896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 304      |
# |    time_elapsed     | 183      |
# |    total_timesteps  | 55950    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.278    |
# |    n_updates        | 6981     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 305      |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 56904    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.15     |
# |    n_updates        | 7100     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 306      |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 57750    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 7206     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 305      |
# |    time_elapsed     | 191      |
# |    total_timesteps  | 58352    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.203    |
# |    n_updates        | 7281     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 307      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 59552    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0998   |
# |    n_updates        | 7431     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 308      |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 60508    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0712   |
# |    n_updates        | 7551     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 306      |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 60792    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.217    |
# |    n_updates        | 7586     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 306      |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 61712    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.435    |
# |    n_updates        | 7701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 306      |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 62454    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.135    |
# |    n_updates        | 7794     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 307      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 63514    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.24     |
# |    n_updates        | 7927     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 308      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 64256    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.95     |
# |    n_updates        | 8019     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 310      |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 65456    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.175    |
# |    n_updates        | 8169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 309      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 66168    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0822   |
# |    n_updates        | 8258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 309      |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 67066    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 8371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 311      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 68266    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.1      |
# |    n_updates        | 8521     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 308      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 68346    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.111    |
# |    n_updates        | 8531     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 309      |
# |    time_elapsed     | 224      |
# |    total_timesteps  | 69486    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.267    |
# |    n_updates        | 8673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 309      |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 70086    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.217    |
# |    n_updates        | 8748     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 308      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 70750    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.77     |
# |    n_updates        | 8831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 310      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 71950    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.81     |
# |    n_updates        | 8981     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 311      |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 73026    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.176    |
# |    n_updates        | 9116     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 311      |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 73688    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.82     |
# |    n_updates        | 9198     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 312      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 74888    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.466    |
# |    n_updates        | 9348     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 312      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 75624    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.142    |
# |    n_updates        | 9440     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 313      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 76788    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.387    |
# |    n_updates        | 9586     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 315      |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 77988    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.113    |
# |    n_updates        | 9736     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 315      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 78870    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0628   |
# |    n_updates        | 9846     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 314      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 79470    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.212    |
# |    n_updates        | 9921     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 313      |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 80086    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0589   |
# |    n_updates        | 9998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 312      |
# |    time_elapsed     | 257      |
# |    total_timesteps  | 80566    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.243    |
# |    n_updates        | 10058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 311      |
# |    time_elapsed     | 260      |
# |    total_timesteps  | 81190    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.079    |
# |    n_updates        | 10136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 311      |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 81800    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.187    |
# |    n_updates        | 10212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 312      |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 83000    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0592   |
# |    n_updates        | 10362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 312      |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 83930    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0779   |
# |    n_updates        | 10479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1832     |
# |    fps              | 299      |
# |    time_elapsed     | 1140     |
# |    total_timesteps  | 341024   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0334   |
# |    n_updates        | 42615    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1836     |
# |    fps              | 299      |
# |    time_elapsed     | 1142     |
# |    total_timesteps  | 341692   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.138    |
# |    n_updates        | 42699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1840     |
# |    fps              | 299      |
# |    time_elapsed     | 1145     |
# |    total_timesteps  | 342500   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.462    |
# |    n_updates        | 42800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1844     |
# |    fps              | 299      |
# |    time_elapsed     | 1147     |
# |    total_timesteps  | 343700   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.156    |
# |    n_updates        | 42950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1848     |
# |    fps              | 299      |
# |    time_elapsed     | 1149     |
# |    total_timesteps  | 344764   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.262    |
# |    n_updates        | 43083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1852     |
# |    fps              | 299      |
# |    time_elapsed     | 1151     |
# |    total_timesteps  | 345500   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0976   |
# |    n_updates        | 43175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1856     |
# |    fps              | 299      |
# |    time_elapsed     | 1154     |
# |    total_timesteps  | 346100   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.109    |
# |    n_updates        | 43250    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1860     |
# |    fps              | 299      |
# |    time_elapsed     | 1156     |
# |    total_timesteps  | 346886   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0889   |
# |    n_updates        | 43348    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1864     |
# |    fps              | 300      |
# |    time_elapsed     | 1159     |
# |    total_timesteps  | 347884   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0458   |
# |    n_updates        | 43473    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1868     |
# |    fps              | 300      |
# |    time_elapsed     | 1161     |
# |    total_timesteps  | 349084   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0847   |
# |    n_updates        | 43623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1872     |
# |    fps              | 300      |
# |    time_elapsed     | 1163     |
# |    total_timesteps  | 349742   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.109    |
# |    n_updates        | 43705    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1876     |
# |    fps              | 300      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 350286   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0966   |
# |    n_updates        | 43773    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1880     |
# |    fps              | 300      |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 351062   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0591   |
# |    n_updates        | 43870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1884     |
# |    fps              | 299      |
# |    time_elapsed     | 1170     |
# |    total_timesteps  | 351070   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0918   |
# |    n_updates        | 43871    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1888     |
# |    fps              | 300      |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 352148   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 44006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1892     |
# |    fps              | 300      |
# |    time_elapsed     | 1175     |
# |    total_timesteps  | 352872   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.311    |
# |    n_updates        | 44096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1896     |
# |    fps              | 300      |
# |    time_elapsed     | 1177     |
# |    total_timesteps  | 353644   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.079    |
# |    n_updates        | 44193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 300      |
# |    time_elapsed     | 1180     |
# |    total_timesteps  | 354244   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.14     |
# |    n_updates        | 44268    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1904     |
# |    fps              | 300      |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 355278   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.157    |
# |    n_updates        | 44397    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1908     |
# |    fps              | 300      |
# |    time_elapsed     | 1184     |
# |    total_timesteps  | 356440   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.873    |
# |    n_updates        | 44542    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1912     |
# |    fps              | 300      |
# |    time_elapsed     | 1187     |
# |    total_timesteps  | 357128   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.101    |
# |    n_updates        | 44628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1916     |
# |    fps              | 300      |
# |    time_elapsed     | 1189     |
# |    total_timesteps  | 357766   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 44708    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1920     |
# |    fps              | 300      |
# |    time_elapsed     | 1192     |
# |    total_timesteps  | 358368   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.304    |
# |    n_updates        | 44783    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1924     |
# |    fps              | 300      |
# |    time_elapsed     | 1194     |
# |    total_timesteps  | 359568   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 44933    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1928     |
# |    fps              | 300      |
# |    time_elapsed     | 1196     |
# |    total_timesteps  | 360240   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 45017    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1932     |
# |    fps              | 301      |
# |    time_elapsed     | 1199     |
# |    total_timesteps  | 361370   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 45159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1936     |
# |    fps              | 301      |
# |    time_elapsed     | 1202     |
# |    total_timesteps  | 362524   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 45303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1940     |
# |    fps              | 301      |
# |    time_elapsed     | 1204     |
# |    total_timesteps  | 363124   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.772    |
# |    n_updates        | 45378    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1944     |
# |    fps              | 300      |
# |    time_elapsed     | 1206     |
# |    total_timesteps  | 363154   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.395    |
# |    n_updates        | 45382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1948     |
# |    fps              | 300      |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 363730   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.046    |
# |    n_updates        | 45454    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1952     |
# |    fps              | 300      |
# |    time_elapsed     | 1211     |
# |    total_timesteps  | 364334   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0507   |
# |    n_updates        | 45529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1956     |
# |    fps              | 300      |
# |    time_elapsed     | 1214     |
# |    total_timesteps  | 364958   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0581   |
# |    n_updates        | 45607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1960     |
# |    fps              | 300      |
# |    time_elapsed     | 1216     |
# |    total_timesteps  | 365508   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.429    |
# |    n_updates        | 45676    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1964     |
# |    fps              | 300      |
# |    time_elapsed     | 1218     |
# |    total_timesteps  | 366166   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.128    |
# |    n_updates        | 45758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 1968     |
# |    fps              | 300      |
# |    time_elapsed     | 1221     |
# |    total_timesteps  | 366944   |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0612   |
# |    n_updates        | 45855    |
# ----------------------------------
# Training Interrupted

# %%
def make_env():
    env = IntelliGoal()
    return env

num_envs = 2
take_logs = False
device = "cuda"

if take_logs:
    log_dir = "./logs/ppo_intelligoal_a3_explore-more"
else:
    log_dir = None
      
if num_envs == 1:
    env = DummyVecEnv([make_env] * num_envs)
else:
    env = SubprocVecEnv([make_env] * num_envs)

# %%
# Load and resume training from saved model
try:
    model.load(path = save_path, env = env)
    model.learn(total_timesteps=100000000, reset_num_timesteps=False, progress_bar=False)
    model.save(save_path)
except KeyboardInterrupt:
    print("Training Interrupted")
    print("Saving Model")
    model.save(save_path)
# Out:
# Logging to ./logs/dqn_intelligoal_tensorboard/DQN_4
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 5952     |
# |    fps              | 356      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1131151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.446    |
# |    n_updates        | 236897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 5956     |
# |    fps              | 456      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1133151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.416    |
# |    n_updates        | 237397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 5960     |
# |    fps              | 479      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 1135151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0922   |
# |    n_updates        | 237897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 5964     |
# |    fps              | 491      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 1137151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.225    |
# |    n_updates        | 238397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 5968     |
# |    fps              | 502      |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 1139151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0845   |
# |    n_updates        | 238897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 5972     |
# |    fps              | 509      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 1141151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 239397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 5976     |
# |    fps              | 515      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 1143151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.11     |
# |    n_updates        | 239897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 5980     |
# |    fps              | 517      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 1145151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0403   |
# |    n_updates        | 240397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 5984     |
# |    fps              | 520      |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 1147151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.112    |
# |    n_updates        | 240897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 5988     |
# |    fps              | 523      |
# |    time_elapsed     | 36       |
# |    total_timesteps  | 1149151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0897   |
# |    n_updates        | 241397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 5992     |
# |    fps              | 524      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 1151151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0567   |
# |    n_updates        | 241897   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 5996     |
# |    fps              | 525      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 1153151  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0675   |
# |    n_updates        | 242397   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 6000     |
# |    fps              | 517      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 1154652  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0774   |
# |    n_updates        | 242772   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 6004     |
# |    fps              | 517      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 1156652  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0649   |
# |    n_updates        | 243272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 6008     |
# |    fps              | 515      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 1158652  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0469   |
# |    n_updates        | 243772   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 6012     |
# |    fps              | 516      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 1160652  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.326    |
# |    n_updates        | 244272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 6016     |
# |    fps              | 516      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 1162652  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0873   |
# |    n_updates        | 244772   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 6020     |
# |    fps              | 516      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 1164652  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.166    |
# |    n_updates        | 245272   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 6024     |
# |    fps              | 513      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 1166455  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0629   |
# |    n_updates        | 245723   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 6028     |
# |    fps              | 511      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 1168363  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0903   |
# |    n_updates        | 246200   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 6032     |
# |    fps              | 511      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 1170363  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0884   |
# |    n_updates        | 246700   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 6036     |
# |    fps              | 510      |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 1172363  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 247200   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 6040     |
# |    fps              | 503      |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 1173864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0902   |
# |    n_updates        | 247575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 6044     |
# |    fps              | 499      |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 1175864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.12     |
# |    n_updates        | 248075   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 6048     |
# |    fps              | 497      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 1177864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.135    |
# |    n_updates        | 248575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 6052     |
# |    fps              | 498      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 1179864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.155    |
# |    n_updates        | 249075   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 6056     |
# |    fps              | 499      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 1181864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.154    |
# |    n_updates        | 249575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 6060     |
# |    fps              | 500      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 1183864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0813   |
# |    n_updates        | 250075   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 6064     |
# |    fps              | 501      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 1185864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 250575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 6068     |
# |    fps              | 501      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 1187864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.153    |
# |    n_updates        | 251075   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 6072     |
# |    fps              | 502      |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 1189864  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0584   |
# |    n_updates        | 251575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 6076     |
# |    fps              | 499      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 1191365  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0864   |
# |    n_updates        | 251950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 6080     |
# |    fps              | 496      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 1193365  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.5      |
# |    n_updates        | 252450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 6084     |
# |    fps              | 495      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 1195365  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0627   |
# |    n_updates        | 252950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 6088     |
# |    fps              | 496      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 1197365  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 253450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 6092     |
# |    fps              | 497      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 1199365  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0542   |
# |    n_updates        | 253950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 6096     |
# |    fps              | 497      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 1201365  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0868   |
# |    n_updates        | 254450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 6100     |
# |    fps              | 498      |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 1203365  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0491   |
# |    n_updates        | 254950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 6104     |
# |    fps              | 499      |
# |    time_elapsed     | 150      |
# |    total_timesteps  | 1205365  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0455   |
# |    n_updates        | 255450   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 6108     |
# |    fps              | 498      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 1207326  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0594   |
# |    n_updates        | 255940   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 6112     |
# |    fps              | 499      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 1209326  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.14     |
# |    n_updates        | 256440   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 6116     |
# |    fps              | 496      |
# |    time_elapsed     | 162      |
# |    total_timesteps  | 1210827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0708   |
# |    n_updates        | 256816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 6120     |
# |    fps              | 495      |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 1212827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0595   |
# |    n_updates        | 257316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 6124     |
# |    fps              | 495      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 1214827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0606   |
# |    n_updates        | 257816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 6128     |
# |    fps              | 495      |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 1216827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0709   |
# |    n_updates        | 258316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 6132     |
# |    fps              | 496      |
# |    time_elapsed     | 178      |
# |    total_timesteps  | 1218827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.134    |
# |    n_updates        | 258816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 6136     |
# |    fps              | 496      |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 1220827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0682   |
# |    n_updates        | 259316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 6140     |
# |    fps              | 497      |
# |    time_elapsed     | 186      |
# |    total_timesteps  | 1222827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0817   |
# |    n_updates        | 259816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 6144     |
# |    fps              | 497      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 1224827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0575   |
# |    n_updates        | 260316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 6148     |
# |    fps              | 498      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 1226827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0533   |
# |    n_updates        | 260816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 6152     |
# |    fps              | 498      |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 1228827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0609   |
# |    n_updates        | 261316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 6156     |
# |    fps              | 499      |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 1230827  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0424   |
# |    n_updates        | 261816   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 6160     |
# |    fps              | 497      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 1232328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0478   |
# |    n_updates        | 262191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 6164     |
# |    fps              | 496      |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 1234328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.132    |
# |    n_updates        | 262691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 6168     |
# |    fps              | 497      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 1236328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0494   |
# |    n_updates        | 263191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 6172     |
# |    fps              | 497      |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 1238328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.067    |
# |    n_updates        | 263691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 6176     |
# |    fps              | 497      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 1240328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0702   |
# |    n_updates        | 264191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 6180     |
# |    fps              | 498      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 1242328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.083    |
# |    n_updates        | 264691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 6184     |
# |    fps              | 498      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 1244328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0434   |
# |    n_updates        | 265191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 6188     |
# |    fps              | 498      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 1246328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0703   |
# |    n_updates        | 265691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 6192     |
# |    fps              | 498      |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 1248328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.152    |
# |    n_updates        | 266191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.878    |
# | time/               |          |
# |    episodes         | 6196     |
# |    fps              | 498      |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 1250328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0743   |
# |    n_updates        | 266691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 6200     |
# |    fps              | 495      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 1252328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0439   |
# |    n_updates        | 267191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 6204     |
# |    fps              | 492      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 1254328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0544   |
# |    n_updates        | 267691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 6208     |
# |    fps              | 491      |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 1256328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0776   |
# |    n_updates        | 268191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 6212     |
# |    fps              | 490      |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 1258328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0789   |
# |    n_updates        | 268691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 6216     |
# |    fps              | 488      |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 1260328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0689   |
# |    n_updates        | 269191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 6220     |
# |    fps              | 487      |
# |    time_elapsed     | 270      |
# |    total_timesteps  | 1262328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0601   |
# |    n_updates        | 269691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 6224     |
# |    fps              | 486      |
# |    time_elapsed     | 275      |
# |    total_timesteps  | 1264328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0676   |
# |    n_updates        | 270191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 6228     |
# |    fps              | 484      |
# |    time_elapsed     | 281      |
# |    total_timesteps  | 1266328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.069    |
# |    n_updates        | 270691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 6232     |
# |    fps              | 482      |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 1268328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.149    |
# |    n_updates        | 271191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 6236     |
# |    fps              | 481      |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 1270328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.164    |
# |    n_updates        | 271691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 6240     |
# |    fps              | 480      |
# |    time_elapsed     | 295      |
# |    total_timesteps  | 1272328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0681   |
# |    n_updates        | 272191   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 6244     |
# |    fps              | 480      |
# |    time_elapsed     | 300      |
# |    total_timesteps  | 1274328  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0521   |
# |    n_updates        | 272691   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 6248     |
# |    fps              | 478      |
# |    time_elapsed     | 304      |
# |    total_timesteps  | 1275829  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.198    |
# |    n_updates        | 273066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 6252     |
# |    fps              | 477      |
# |    time_elapsed     | 309      |
# |    total_timesteps  | 1277829  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.122    |
# |    n_updates        | 273566   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 6256     |
# |    fps              | 476      |
# |    time_elapsed     | 314      |
# |    total_timesteps  | 1279829  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0497   |
# |    n_updates        | 274066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 6260     |
# |    fps              | 475      |
# |    time_elapsed     | 318      |
# |    total_timesteps  | 1281829  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0569   |
# |    n_updates        | 274566   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 6264     |
# |    fps              | 475      |
# |    time_elapsed     | 323      |
# |    total_timesteps  | 1283829  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.116    |
# |    n_updates        | 275066   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 6268     |
# |    fps              | 475      |
# |    time_elapsed     | 327      |
# |    total_timesteps  | 1285829  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.124    |
# |    n_updates        | 275566   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 6272     |
# |    fps              | 475      |
# |    time_elapsed     | 331      |
# |    total_timesteps  | 1287428  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.945    |
# |    n_updates        | 275966   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 6276     |
# |    fps              | 475      |
# |    time_elapsed     | 335      |
# |    total_timesteps  | 1289428  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.104    |
# |    n_updates        | 276466   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 6280     |
# |    fps              | 475      |
# |    time_elapsed     | 338      |
# |    total_timesteps  | 1291428  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0801   |
# |    n_updates        | 276966   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 6284     |
# |    fps              | 475      |
# |    time_elapsed     | 343      |
# |    total_timesteps  | 1293402  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.084    |
# |    n_updates        | 277459   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 6288     |
# |    fps              | 474      |
# |    time_elapsed     | 348      |
# |    total_timesteps  | 1295402  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0751   |
# |    n_updates        | 277959   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 6292     |
# |    fps              | 472      |
# |    time_elapsed     | 353      |
# |    total_timesteps  | 1296903  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0484   |
# |    n_updates        | 278335   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 6296     |
# |    fps              | 470      |
# |    time_elapsed     | 358      |
# |    total_timesteps  | 1298903  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0424   |
# |    n_updates        | 278835   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 6300     |
# |    fps              | 469      |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 1300903  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0556   |
# |    n_updates        | 279335   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 6304     |
# |    fps              | 469      |
# |    time_elapsed     | 368      |
# |    total_timesteps  | 1302903  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 279835   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 6308     |
# |    fps              | 467      |
# |    time_elapsed     | 372      |
# |    total_timesteps  | 1304404  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0637   |
# |    n_updates        | 280210   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 6312     |
# |    fps              | 466      |
# |    time_elapsed     | 377      |
# |    total_timesteps  | 1306404  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0569   |
# |    n_updates        | 280710   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 6316     |
# |    fps              | 465      |
# |    time_elapsed     | 382      |
# |    total_timesteps  | 1308404  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0518   |
# |    n_updates        | 281210   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 6320     |
# |    fps              | 463      |
# |    time_elapsed     | 387      |
# |    total_timesteps  | 1309905  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.064    |
# |    n_updates        | 281585   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.872    |
# | time/               |          |
# |    episodes         | 6324     |
# |    fps              | 462      |
# |    time_elapsed     | 393      |
# |    total_timesteps  | 1311905  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0403   |
# |    n_updates        | 282085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 6328     |
# |    fps              | 461      |
# |    time_elapsed     | 397      |
# |    total_timesteps  | 1313905  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0669   |
# |    n_updates        | 282585   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 6332     |
# |    fps              | 461      |
# |    time_elapsed     | 402      |
# |    total_timesteps  | 1315905  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0352   |
# |    n_updates        | 283085   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 6336     |
# |    fps              | 460      |
# |    time_elapsed     | 407      |
# |    total_timesteps  | 1317902  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0424   |
# |    n_updates        | 283584   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 6340     |
# |    fps              | 460      |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 1319902  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0819   |
# |    n_updates        | 284084   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 6344     |
# |    fps              | 459      |
# |    time_elapsed     | 415      |
# |    total_timesteps  | 1321403  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0573   |
# |    n_updates        | 284460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 6348     |
# |    fps              | 459      |
# |    time_elapsed     | 420      |
# |    total_timesteps  | 1323403  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0627   |
# |    n_updates        | 284960   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 6352     |
# |    fps              | 459      |
# |    time_elapsed     | 425      |
# |    total_timesteps  | 1325403  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.074    |
# |    n_updates        | 285460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 6356     |
# |    fps              | 458      |
# |    time_elapsed     | 430      |
# |    total_timesteps  | 1327403  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0434   |
# |    n_updates        | 285960   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 6360     |
# |    fps              | 457      |
# |    time_elapsed     | 435      |
# |    total_timesteps  | 1329403  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0427   |
# |    n_updates        | 286460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 6364     |
# |    fps              | 457      |
# |    time_elapsed     | 439      |
# |    total_timesteps  | 1331403  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0436   |
# |    n_updates        | 286960   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.869    |
# | time/               |          |
# |    episodes         | 6368     |
# |    fps              | 457      |
# |    time_elapsed     | 444      |
# |    total_timesteps  | 1333403  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0921   |
# |    n_updates        | 287460   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.869    |
# | time/               |          |
# ...
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 7552     |
# |    fps              | 448      |
# |    time_elapsed     | 1733     |
# |    total_timesteps  | 1907834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0781   |
# |    n_updates        | 431067   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 7556     |
# |    fps              | 448      |
# |    time_elapsed     | 1738     |
# |    total_timesteps  | 1909834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0619   |
# |    n_updates        | 431567   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 7560     |
# |    fps              | 448      |
# |    time_elapsed     | 1742     |
# |    total_timesteps  | 1911834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0665   |
# |    n_updates        | 432067   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.813    |
# | time/               |          |
# |    episodes         | 7564     |
# |    fps              | 448      |
# |    time_elapsed     | 1746     |
# |    total_timesteps  | 1913834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0569   |
# |    n_updates        | 432567   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 7568     |
# |    fps              | 448      |
# |    time_elapsed     | 1751     |
# |    total_timesteps  | 1915834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0703   |
# |    n_updates        | 433067   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 7572     |
# |    fps              | 448      |
# |    time_elapsed     | 1756     |
# |    total_timesteps  | 1917834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0428   |
# |    n_updates        | 433567   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 7576     |
# |    fps              | 448      |
# |    time_elapsed     | 1760     |
# |    total_timesteps  | 1919834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0869   |
# |    n_updates        | 434067   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 7580     |
# |    fps              | 448      |
# |    time_elapsed     | 1764     |
# |    total_timesteps  | 1921834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 434567   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 7584     |
# |    fps              | 448      |
# |    time_elapsed     | 1768     |
# |    total_timesteps  | 1923834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0626   |
# |    n_updates        | 435067   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 7588     |
# |    fps              | 448      |
# |    time_elapsed     | 1772     |
# |    total_timesteps  | 1925834  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 1.12     |
# |    n_updates        | 435567   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 7592     |
# |    fps              | 448      |
# |    time_elapsed     | 1776     |
# |    total_timesteps  | 1927338  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0776   |
# |    n_updates        | 435943   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 7596     |
# |    fps              | 448      |
# |    time_elapsed     | 1780     |
# |    total_timesteps  | 1929338  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0768   |
# |    n_updates        | 436443   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 7600     |
# |    fps              | 449      |
# |    time_elapsed     | 1784     |
# |    total_timesteps  | 1931338  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0608   |
# |    n_updates        | 436943   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 7604     |
# |    fps              | 448      |
# |    time_elapsed     | 1788     |
# |    total_timesteps  | 1933210  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.068    |
# |    n_updates        | 437411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.811    |
# | time/               |          |
# |    episodes         | 7608     |
# |    fps              | 449      |
# |    time_elapsed     | 1792     |
# |    total_timesteps  | 1935210  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0958   |
# |    n_updates        | 437911   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 7612     |
# |    fps              | 449      |
# |    time_elapsed     | 1796     |
# |    total_timesteps  | 1937210  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 438411   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 7616     |
# |    fps              | 449      |
# |    time_elapsed     | 1801     |
# |    total_timesteps  | 1939210  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0712   |
# |    n_updates        | 438911   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 7620     |
# |    fps              | 449      |
# |    time_elapsed     | 1805     |
# |    total_timesteps  | 1941159  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0854   |
# |    n_updates        | 439399   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 7624     |
# |    fps              | 449      |
# |    time_elapsed     | 1810     |
# |    total_timesteps  | 1943159  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.327    |
# |    n_updates        | 439899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.81     |
# | time/               |          |
# |    episodes         | 7628     |
# |    fps              | 449      |
# |    time_elapsed     | 1814     |
# |    total_timesteps  | 1944934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0579   |
# |    n_updates        | 440342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 7632     |
# |    fps              | 449      |
# |    time_elapsed     | 1818     |
# |    total_timesteps  | 1946934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0702   |
# |    n_updates        | 440842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 7636     |
# |    fps              | 449      |
# |    time_elapsed     | 1822     |
# |    total_timesteps  | 1948934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0402   |
# |    n_updates        | 441342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 7640     |
# |    fps              | 449      |
# |    time_elapsed     | 1827     |
# |    total_timesteps  | 1950934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0617   |
# |    n_updates        | 441842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 7644     |
# |    fps              | 449      |
# |    time_elapsed     | 1832     |
# |    total_timesteps  | 1952934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.138    |
# |    n_updates        | 442342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.809    |
# | time/               |          |
# |    episodes         | 7648     |
# |    fps              | 449      |
# |    time_elapsed     | 1836     |
# |    total_timesteps  | 1954934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0546   |
# |    n_updates        | 442842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 7652     |
# |    fps              | 449      |
# |    time_elapsed     | 1841     |
# |    total_timesteps  | 1956934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0671   |
# |    n_updates        | 443342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 7656     |
# |    fps              | 449      |
# |    time_elapsed     | 1845     |
# |    total_timesteps  | 1958934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0638   |
# |    n_updates        | 443842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 7660     |
# |    fps              | 449      |
# |    time_elapsed     | 1849     |
# |    total_timesteps  | 1960934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0657   |
# |    n_updates        | 444342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 7664     |
# |    fps              | 448      |
# |    time_elapsed     | 1854     |
# |    total_timesteps  | 1962934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0834   |
# |    n_updates        | 444842   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 7668     |
# |    fps              | 448      |
# |    time_elapsed     | 1859     |
# |    total_timesteps  | 1964934  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0547   |
# |    n_updates        | 445342   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 7672     |
# |    fps              | 448      |
# |    time_elapsed     | 1863     |
# |    total_timesteps  | 1966435  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0411   |
# |    n_updates        | 445718   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 7676     |
# |    fps              | 448      |
# |    time_elapsed     | 1868     |
# |    total_timesteps  | 1968435  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0748   |
# |    n_updates        | 446218   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 7680     |
# |    fps              | 448      |
# |    time_elapsed     | 1873     |
# |    total_timesteps  | 1970435  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0434   |
# |    n_updates        | 446718   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 7684     |
# |    fps              | 448      |
# |    time_elapsed     | 1877     |
# |    total_timesteps  | 1972435  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0894   |
# |    n_updates        | 447218   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 7688     |
# |    fps              | 448      |
# |    time_elapsed     | 1881     |
# |    total_timesteps  | 1974435  |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0878   |
# |    n_updates        | 447718   |
# ----------------------------------
# Training Interrupted
# Saving Model

# %%
# Evaluate the model
mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=1)
print(f"Mean Reward: {mean_reward}, Std Reward: {std_reward}")
# Out:
# Mean Reward: 0.48489999771118164, Std Reward: 0.0

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
save_path = "./models/dqn_intelligoal_a1_works-100"

# %%
def make_env():
    def _init():
        env = IntelliGoal()
        env.render_mode = 'human'
        return env
    return _init

# Wrap your environment in a DummyVecEnv for compatibility
env = DummyVecEnv([make_env()])

model = DQN.load(save_path, env=env, device=device)

def run_model():
    obs = env.reset()  # This will now be in the correct batch format
    done = False
    while True:
        action, _states = model.predict(obs, deterministic=True)
        obs, rewards, done, info = env.step(action)
        env.render()
        if done:
            print("Episode Finished with Reward - ", rewards[0])
            obs = env.reset()

try:
    run_model()
except:
    print("Environment Closed")
# Out:
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -0.775
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Episode Finished with Reward -  -1.0
# Environment Closed

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
